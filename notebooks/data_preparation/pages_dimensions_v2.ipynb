# %% [markdown]
# # Get Page Dimension from Images

# %%
import os
import cv2
import pandas as pd

import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, as_completed

from tqdm import tqdm

# %%
test_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/test.csv")
train_small_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/train_small.csv")
train_large_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/train_large.csv")

# %%
# pages_df = pd.concat([test_sample, train_small_sample, train_large_sample], ignore_index=True).drop_duplicates(subset="page_id")
pages_df = pd.concat([train_large_sample], ignore_index=True).drop_duplicates(subset="page_id")
pages_df["issue_id"] = pages_df["page_id"].apply(lambda x: x.split("-p")[0])
pages_df
# Out:
#          journal                      page_id               issue_id
# 0           jdpl      jdpl-1814-05-22-a-p0001      jdpl-1814-05-22-a
# 1           jdpl      jdpl-1814-06-05-a-p0001      jdpl-1814-06-05-a
# 2           jdpl      jdpl-1814-07-26-a-p0001      jdpl-1814-07-26-a
# 3           jdpl      jdpl-1814-06-08-a-p0001      jdpl-1814-06-08-a
# 4           jdpl      jdpl-1814-07-29-a-p0001      jdpl-1814-07-29-a
# ...          ...                          ...                    ...
# 149995    oeuvre    oeuvre-1934-07-12-a-p0002    oeuvre-1934-07-12-a
# 149996  indeplux  indeplux-1905-11-03-a-p0001  indeplux-1905-11-03-a
# 149997      jdpl      jdpl-1930-12-02-a-p0006      jdpl-1930-12-02-a
# 149998    oeuvre    oeuvre-1923-05-09-a-p0006    oeuvre-1923-05-09-a
# 149999    oeuvre    oeuvre-1916-05-26-a-p0002    oeuvre-1916-05-26-a
#
# [150000 rows x 3 columns]

# %%
pages_df["file_name"] = pages_df["page_id"].apply(lambda x: x+".jpg")
pages_df["width"] = 7000 # Placeholder !!!
pages_df["height"] = 8000

pages_df
# Out:
#          journal                      page_id               issue_id  \
# 0           jdpl      jdpl-1814-05-22-a-p0001      jdpl-1814-05-22-a
# 1           jdpl      jdpl-1814-06-05-a-p0001      jdpl-1814-06-05-a
# 2           jdpl      jdpl-1814-07-26-a-p0001      jdpl-1814-07-26-a
# 3           jdpl      jdpl-1814-06-08-a-p0001      jdpl-1814-06-08-a
# 4           jdpl      jdpl-1814-07-29-a-p0001      jdpl-1814-07-29-a
# ...          ...                          ...                    ...
# 149995    oeuvre    oeuvre-1934-07-12-a-p0002    oeuvre-1934-07-12-a
# 149996  indeplux  indeplux-1905-11-03-a-p0001  indeplux-1905-11-03-a
# 149997      jdpl      jdpl-1930-12-02-a-p0006      jdpl-1930-12-02-a
# 149998    oeuvre    oeuvre-1923-05-09-a-p0006    oeuvre-1923-05-09-a
# 149999    oeuvre    oeuvre-1916-05-26-a-p0002    oeuvre-1916-05-26-a
#
#                               file_name  width  height
# 0           jdpl-1814-05-22-a-p0001.jpg   7000    8000
# 1           jdpl-1814-06-05-a-p0001.jpg   7000    8000
# 2           jdpl-1814-07-26-a-p0001.jpg   7000    8000
# 3           jdpl-1814-06-08-a-p0001.jpg   7000    8000
# 4           jdpl-1814-07-29-a-p0001.jpg   7000    8000
# ...                                 ...    ...     ...
# 149995    oeuvre-1934-07-12-a-p0002.jpg   7000    8000
# 149996  indeplux-1905-11-03-a-p0001.jpg   7000    8000
# 149997      jdpl-1930-12-02-a-p0006.jpg   7000    8000
# 149998    oeuvre-1923-05-09-a-p0006.jpg   7000    8000
# 149999    oeuvre-1916-05-26-a-p0002.jpg   7000    8000
#
# [150000 rows x 6 columns]

# %%
def get_img_dim(img_dir, image_fn):
    image_path = os.path.join(img_dir, image_fn)
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"Failed to load image: {image_path}")
    image_height, image_width, _ = image.shape
    
    return image_fn, image_height, image_width

# %%
img_dir = "/scratch/students/danae/data/images"

# concurrent execution
results = []
error_log = []

MAX_THREADS = 15 # number of concurrent requests
TIMEOUT = 5

def get_img_dim_safe(img_dir, file_name):
    """
    A wrapper for get_img_dim to handle warnings and errors.
    """
    try:
        return get_img_dim(img_dir, file_name)
    except Exception as e:
        raise RuntimeError(f"Error reading {file_name}: {e}")

with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
    # submit all file names to the executor
    future_to_url = {
        executor.submit(get_img_dim_safe, img_dir, fn): fn
        for fn in pages_df["file_name"]
    }
    
    for future in tqdm(concurrent.futures.as_completed(future_to_url), total=len(future_to_url), desc="Fetching image dimensions"):
        file_name = future_to_url[future]
        try:
            # collect results as they complete, within the timeout
            result = future.result(timeout=TIMEOUT)
            results.append(result)
        except concurrent.futures.TimeoutError:
            # log timeout error
            error_log.append({"file_name": file_name, "error": "Timeout"})
        except Exception as e:
            # log other errors
            error_log.append({"file_name": file_name, "error": str(e)})


page_dimensions = pd.DataFrame(results, columns=["file_name", "img_height", "image_width"])
error_log_df = pd.DataFrame(error_log)
# Out:
# Fetching image dimensions:   0%|          | 248/150000 [00:05<1:16:32, 32.61it/s]Premature end of JPEG file
# Fetching image dimensions:   3%|▎         | 4946/150000 [02:45<2:45:21, 14.62it/s][ WARN:0@177.059] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1852-01-01-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:   4%|▍         | 6276/150000 [03:26<2:31:45, 15.78it/s]Premature end of JPEG file
# Fetching image dimensions:   5%|▌         | 7641/150000 [04:10<1:46:35, 22.26it/s][ WARN:1@261.504] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/luxwort-1860-11-01-a-p0002.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:   5%|▌         | 7868/150000 [04:20<1:24:43, 27.96it/s]Premature end of JPEG file
# Fetching image dimensions:   6%|▋         | 9638/150000 [05:27<2:14:36, 17.38it/s][ WARN:2@338.634] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1864-01-15-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:   6%|▋         | 9643/150000 [05:27<2:16:23, 17.15it/s][ WARN:1@338.877] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1864-01-20-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:   8%|▊         | 11588/150000 [06:27<1:43:07, 22.37it/s]Premature end of JPEG file
# Fetching image dimensions:   8%|▊         | 12692/150000 [06:59<13:50, 165.30it/s] Premature end of JPEG file
# Fetching image dimensions:   8%|▊         | 12749/150000 [07:03<1:43:43, 22.05it/s][ WARN:1@435.211] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1870-01-23-b-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:   9%|▊         | 12773/150000 [07:05<1:59:32, 19.13it/s][ WARN:3@436.630] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1870-01-23-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:   9%|▉         | 13299/150000 [07:22<1:29:33, 25.44it/s][ WARN:4@454.951] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1871-12-09-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  10%|█         | 15150/150000 [08:26<2:43:50, 13.72it/s]Premature end of JPEG file
# Fetching image dimensions:  11%|█         | 16249/150000 [09:07<2:07:52, 17.43it/s]Premature end of JPEG file
# Fetching image dimensions:  11%|█▏        | 16920/150000 [09:37<2:36:39, 14.16it/s]Premature end of JPEG file
# Fetching image dimensions:  11%|█▏        | 16924/150000 [09:37<2:46:24, 13.33it/s][ WARN:4@588.548] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/lepetitparisien-1877-03-12-a-p0001.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  12%|█▏        | 17463/150000 [09:57<2:16:19, 16.20it/s]Premature end of JPEG file
# Fetching image dimensions:  13%|█▎        | 18861/150000 [11:03<2:24:26, 15.13it/s][ WARN:1@674.331] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1880-01-31-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  13%|█▎        | 19473/150000 [11:22<2:38:17, 13.74it/s][ WARN:4@693.339] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-03-11-a-p0003.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@693.350] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-03-30-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  13%|█▎        | 19516/150000 [11:24<2:51:35, 12.67it/s][ WARN:6@696.196] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-03-19-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  13%|█▎        | 19529/150000 [11:25<1:55:47, 18.78it/s][ WARN:7@696.904] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-04-12-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  13%|█▎        | 19634/150000 [11:33<3:00:53, 12.01it/s]Premature end of JPEG file
# Fetching image dimensions:  13%|█▎        | 20214/150000 [11:58<1:53:30, 19.06it/s]Premature end of JPEG file
# Fetching image dimensions:  16%|█▌        | 23415/150000 [14:18<2:46:45, 12.65it/s][ WARN:0@869.961] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1887-03-27-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  16%|█▌        | 23437/150000 [14:20<2:46:45, 12.65it/s][ WARN:5@871.534] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1887-03-27-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  16%|█▌        | 24357/150000 [15:06<1:52:23, 18.63it/s]Premature end of JPEG file
# Fetching image dimensions:  17%|█▋        | 25976/150000 [16:28<2:14:18, 15.39it/s]Premature end of JPEG file
# Fetching image dimensions:  18%|█▊        | 26609/150000 [16:58<2:24:48, 14.20it/s][ WARN:3@1029.582] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1891-09-30-b-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  18%|█▊        | 26635/150000 [17:00<3:13:37, 10.62it/s][ WARN:6@1031.529] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1891-09-30-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  19%|█▉        | 28164/150000 [18:10<1:57:24, 17.30it/s][ WARN:7@1101.806] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1893-05-02-c-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  19%|█▉        | 28181/150000 [18:11<1:48:49, 18.66it/s][ WARN:7@1102.841] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1893-11-16-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  19%|█▉        | 28187/150000 [18:12<2:22:50, 14.21it/s][ WARN:3@1103.323] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1893-05-02-c-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  19%|█▉        | 29080/150000 [18:56<2:51:37, 11.74it/s][ WARN:8@1147.816] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1894-11-24-b-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  19%|█▉        | 29103/150000 [18:58<2:52:48, 11.66it/s][ WARN:9@1149.685] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1894-11-24-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  20%|█▉        | 29787/150000 [19:25<2:02:05, 16.41it/s]Premature end of JPEG file
# Fetching image dimensions:  20%|██        | 30519/150000 [20:04<3:29:26,  9.51it/s][ WARN:6@1216.172] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1896-11-27-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  20%|██        | 30539/150000 [20:06<2:56:05, 11.31it/s][ WARN:7@1217.937] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1896-11-27-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  20%|██        | 30593/150000 [20:10<2:09:53, 15.32it/s][ WARN:3@1222.016] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1896-05-04-b-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  20%|██        | 30611/150000 [20:12<2:29:11, 13.34it/s][ WARN:10@1223.502] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1896-05-04-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  21%|██        | 31262/150000 [20:47<2:34:47, 12.79it/s]Premature end of JPEG file
# Fetching image dimensions:  22%|██▏       | 32729/150000 [22:11<2:44:11, 11.90it/s][ WARN:10@1342.696] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1899-12-29-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  22%|██▏       | 32747/150000 [22:13<4:06:28,  7.93it/s][ WARN:0@1344.562] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1899-12-29-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  22%|██▏       | 33545/150000 [22:53<3:06:55, 10.38it/s][ WARN:3@1384.749] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1900-06-22-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  22%|██▏       | 33560/150000 [22:54<3:20:06,  9.70it/s][ WARN:6@1386.175] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1900-06-22-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  23%|██▎       | 34061/150000 [23:18<59:12, 32.63it/s]  [ WARN:11@1409.926] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/indeplux-1901-07-03-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  23%|██▎       | 34337/150000 [23:36<2:56:01, 10.95it/s] Premature end of JPEG file
# Fetching image dimensions:  23%|██▎       | 35201/150000 [24:21<2:35:52, 12.28it/s][ WARN:12@1472.466] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1902-05-21-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  23%|██▎       | 35219/150000 [24:22<2:39:12, 12.02it/s][ WARN:1@1473.959] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1902-05-21-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  24%|██▎       | 35278/150000 [24:27<1:52:14, 17.03it/s]Premature end of JPEG file
# Fetching image dimensions:  25%|██▍       | 36897/150000 [25:45<2:24:00, 13.09it/s]Premature end of JPEG file
# Fetching image dimensions:  25%|██▍       | 37024/150000 [25:52<54:39, 34.45it/s]  [ WARN:12@1564.037] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/lepji-1904-07-24-b-p0009.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  28%|██▊       | 42053/150000 [29:28<2:00:05, 14.98it/s]Premature end of JPEG file
# Fetching image dimensions:  28%|██▊       | 42072/150000 [29:31<3:22:53,  8.87it/s]Premature end of JPEG file
# Fetching image dimensions:  28%|██▊       | 42080/150000 [29:31<2:22:11, 12.65it/s]Premature end of JPEG file
# Fetching image dimensions:  28%|██▊       | 42720/150000 [30:02<1:06:53, 26.73it/s][ WARN:4@1814.093] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/indeplux-1911-03-14-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  29%|██▊       | 42944/150000 [30:13<2:46:00, 10.75it/s]Premature end of JPEG file
# Fetching image dimensions:  29%|██▊       | 42946/150000 [30:13<2:35:06, 11.50it/s]Premature end of JPEG file
# Fetching image dimensions:  30%|███       | 45539/150000 [32:37<1:13:09, 23.80it/s]Premature end of JPEG file
# Fetching image dimensions:  31%|███       | 46756/150000 [33:45<1:55:50, 14.85it/s]Premature end of JPEG file
# Fetching image dimensions:  35%|███▍      | 51752/150000 [38:08<1:47:48, 15.19it/s]Premature end of JPEG file
# Fetching image dimensions:  38%|███▊      | 56716/150000 [42:20<1:24:03, 18.49it/s]Premature end of JPEG file
# Fetching image dimensions:  38%|███▊      | 57039/150000 [42:38<27:55, 55.50it/s]  Premature end of JPEG file
# Fetching image dimensions:  40%|████      | 60740/150000 [45:41<1:53:19, 13.13it/s]Premature end of JPEG file
# Fetching image dimensions:  42%|████▏     | 63038/150000 [47:25<1:21:57, 17.68it/s][ WARN:7@2856.708] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0011.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@2856.709] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0009.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@2856.710] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0013.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  42%|████▏     | 63043/150000 [47:25<1:11:18, 20.32it/s][ WARN:1@2857.044] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0012.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  42%|████▏     | 63054/150000 [47:26<56:26, 25.67it/s]  [ WARN:13@2857.302] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0010.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@2857.302] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0014.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  42%|████▏     | 63077/150000 [47:26<55:18, 26.19it/s]  [ WARN:1@2858.180] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0005.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  42%|████▏     | 63084/150000 [47:27<42:45, 33.88it/s][ WARN:12@2858.314] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0006.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  42%|████▏     | 63089/150000 [47:27<48:38, 29.78it/s][ WARN:0@2858.468] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@2858.489] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oerennes-1932-05-06-b-p0008.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  43%|████▎     | 63777/150000 [47:51<1:49:27, 13.13it/s]Premature end of JPEG file
# Fetching image dimensions:  44%|████▍     | 66220/150000 [49:40<46:13, 30.21it/s]  [ WARN:7@2991.631] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/luxwort-1936-08-18-a-p0009.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  44%|████▍     | 66250/150000 [49:41<42:18, 32.99it/s][ WARN:2@2992.348] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/luxwort-1936-04-22-a-p0010.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  44%|████▍     | 66347/150000 [49:44<49:08, 28.37it/s]  [ WARN:1@2996.033] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/luxwort-1936-03-01-a-p0007.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  44%|████▍     | 66361/150000 [49:45<49:11, 28.34it/s][ WARN:12@2996.595] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/luxwort-1936-03-01-a-p0008.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  45%|████▌     | 67758/150000 [50:50<1:26:45, 15.80it/s][ WARN:2@3061.993] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1937-04-27-a-p0002.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  46%|████▌     | 69281/150000 [51:51<11:44, 114.65it/s] Premature end of JPEG file
# Fetching image dimensions:  82%|████████▏ | 122301/150000 [1:21:33<1:08:51,  6.70it/s][ WARN:11@4905.015] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1869-12-03-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  82%|████████▏ | 123370/150000 [1:23:31<1:00:01,  7.39it/s][ WARN:0@5022.260] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/lematin-1900-08-02-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  82%|████████▏ | 123462/150000 [1:23:41<45:53,  9.64it/s]  [ WARN:7@5032.989] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-02-14-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  83%|████████▎ | 124036/150000 [1:24:47<1:26:31,  5.00it/s]Premature end of JPEG file
# Fetching image dimensions:  83%|████████▎ | 124207/150000 [1:25:06<54:29,  7.89it/s]  [ WARN:11@5117.595] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/oecaen-1913-11-19-a-p0002.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  83%|████████▎ | 124688/150000 [1:25:59<28:16, 14.92it/s]  [ WARN:2@5171.013] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1844-04-13-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  84%|████████▎ | 125435/150000 [1:27:27<53:37,  7.64it/s]  [ WARN:13@5259.001] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-02-18-a-p0001.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  84%|████████▍ | 126213/150000 [1:28:49<40:13,  9.86it/s]  [ WARN:6@5340.274] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1864-05-12-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  84%|████████▍ | 126327/150000 [1:29:01<38:44, 10.18it/s]  [ WARN:4@5352.526] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1893-04-27-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  84%|████████▍ | 126546/150000 [1:29:24<48:43,  8.02it/s]  [ WARN:5@5375.369] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1864-05-11-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  85%|████████▍ | 126816/150000 [1:29:53<46:21,  8.33it/s]  [ WARN:3@5404.330] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1937-06-15-a-p0002.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  85%|████████▍ | 127270/150000 [1:30:43<56:41,  6.68it/s]  [ WARN:9@5454.396] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1820-06-24-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  85%|████████▍ | 127315/150000 [1:30:48<53:47,  7.03it/s][ WARN:7@5459.877] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1831-02-20-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  85%|████████▌ | 127839/150000 [1:31:47<59:27,  6.21it/s]  Premature end of JPEG file
# Fetching image dimensions:  86%|████████▌ | 128952/150000 [1:33:49<38:24,  9.14it/s]  [ WARN:13@5640.538] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1890-10-26-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  87%|████████▋ | 129941/150000 [1:35:40<37:13,  8.98it/s]  Premature end of JPEG file
# Fetching image dimensions:  87%|████████▋ | 130682/150000 [1:37:02<31:00, 10.38it/s][ WARN:6@5833.596] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-03-06-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  87%|████████▋ | 130772/150000 [1:37:11<42:57,  7.46it/s]  Premature end of JPEG file
# Fetching image dimensions:  87%|████████▋ | 130829/150000 [1:37:18<33:25,  9.56it/s]  [ WARN:1@5849.934] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/luxwort-1916-09-22-a-p0005.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  88%|████████▊ | 131438/150000 [1:38:26<39:43,  7.79it/s]  Premature end of JPEG file
# Fetching image dimensions:  88%|████████▊ | 131856/150000 [1:39:11<32:26,  9.32it/s]  Premature end of JPEG file
# Fetching image dimensions:  88%|████████▊ | 132313/150000 [1:40:02<23:24, 12.59it/s]  [ WARN:11@6013.367] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1849-10-13-b-p0005.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  88%|████████▊ | 132613/150000 [1:40:32<34:05,  8.50it/s][ WARN:14@6043.972] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1881-08-06-b-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  89%|████████▉ | 133317/150000 [1:41:48<34:03,  8.16it/s]Premature end of JPEG file
# Fetching image dimensions:  89%|████████▉ | 133850/150000 [1:42:49<27:50,  9.67it/s][ WARN:13@6180.473] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1871-12-06-a-p0001.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  89%|████████▉ | 134100/150000 [1:43:18<29:47,  8.89it/s]Premature end of JPEG file
# Fetching image dimensions:  89%|████████▉ | 134186/150000 [1:43:27<22:26, 11.74it/s][ WARN:9@6218.253] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-02-01-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  90%|████████▉ | 134433/150000 [1:43:54<22:31, 11.52it/s][ WARN:0@6245.364] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1900-11-22-a-p0005.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  90%|████████▉ | 134501/150000 [1:44:02<29:12,  8.84it/s]  [ WARN:1@6253.920] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1896-10-05-b-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  90%|████████▉ | 134546/150000 [1:44:07<26:09,  9.85it/s][ WARN:8@6259.423] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1827-11-08-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  90%|█████████ | 135002/150000 [1:45:01<23:34, 10.60it/s]Premature end of JPEG file
# Fetching image dimensions:  90%|█████████ | 135559/150000 [1:46:00<27:16,  8.82it/s]Premature end of JPEG file
# Fetching image dimensions:  91%|█████████ | 136462/150000 [1:47:44<35:07,  6.43it/s]  Premature end of JPEG file
# Fetching image dimensions:  91%|█████████ | 136536/150000 [1:47:51<29:27,  7.62it/s][ WARN:1@6482.863] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1897-07-07-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  91%|█████████ | 136827/150000 [1:48:24<15:41, 13.99it/s][ WARN:8@6515.366] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1899-03-27-b-p0015.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  92%|█████████▏| 137545/150000 [1:49:42<12:15, 16.92it/s]Premature end of JPEG file
# Fetching image dimensions:  92%|█████████▏| 137982/150000 [1:50:29<21:00,  9.53it/s][ WARN:11@6640.610] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/luxwort-1867-04-24-a-p0006.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  92%|█████████▏| 138295/150000 [1:51:03<19:00, 10.27it/s][ WARN:1@6674.747] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1893-04-17-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  93%|█████████▎| 139402/150000 [1:53:04<18:01,  9.80it/s][ WARN:14@6795.458] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/lematin-1930-03-28-a-p0010.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  93%|█████████▎| 140068/150000 [1:54:14<18:13,  9.08it/s][ WARN:4@6865.704] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-03-01-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  93%|█████████▎| 140167/150000 [1:54:25<15:40, 10.45it/s][ WARN:4@6876.754] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-02-08-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  94%|█████████▍| 140764/150000 [1:55:29<14:11, 10.84it/s]Premature end of JPEG file
# Fetching image dimensions:  94%|█████████▍| 141413/150000 [1:56:43<18:00,  7.95it/s]Premature end of JPEG file
# Fetching image dimensions:  95%|█████████▍| 142045/150000 [1:57:53<13:07, 10.10it/s][ WARN:12@7084.230] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1893-04-05-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  95%|█████████▍| 142244/150000 [1:58:13<15:47,  8.19it/s][ WARN:4@7104.393] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1893-03-28-c-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  96%|█████████▌| 143372/150000 [2:00:17<09:53, 11.16it/s]Premature end of JPEG file
# Fetching image dimensions:  96%|█████████▌| 143731/150000 [2:00:55<06:33, 15.93it/s]Premature end of JPEG file
# Fetching image dimensions:  96%|█████████▋| 144578/150000 [2:02:31<10:50,  8.33it/s][ WARN:0@7362.775] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/luxwort-1936-04-22-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  96%|█████████▋| 144624/150000 [2:02:36<09:24,  9.52it/s][ WARN:0@7367.852] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-05-01-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  97%|█████████▋| 145809/150000 [2:04:46<09:02,  7.73it/s][ WARN:9@7498.034] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1863-11-21-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  98%|█████████▊| 146691/150000 [2:06:21<06:22,  8.65it/s][ WARN:9@7592.977] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-03-10-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  98%|█████████▊| 146971/150000 [2:06:54<05:40,  8.89it/s][ WARN:9@7625.779] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1871-12-02-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  98%|█████████▊| 147022/150000 [2:06:59<03:57, 12.54it/s][ WARN:0@7630.825] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1893-03-28-c-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  99%|█████████▊| 147990/150000 [2:08:48<04:18,  7.77it/s][ WARN:7@7739.910] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1883-08-23-b-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  99%|█████████▊| 148029/150000 [2:08:53<04:43,  6.95it/s]Premature end of JPEG file
# Fetching image dimensions:  99%|█████████▊| 148058/150000 [2:08:56<03:29,  9.25it/s][ WARN:14@7747.796] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1894-04-29-c-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  99%|█████████▉| 148492/150000 [2:09:46<04:04,  6.16it/s][ WARN:6@7797.911] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-02-07-a-p0003.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions:  99%|█████████▉| 148702/150000 [2:10:10<02:41,  8.02it/s][ WARN:8@7821.926] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/lepji-1904-07-24-b-p0010.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions: 100%|█████████▉| 149619/150000 [2:11:52<00:46,  8.21it/s][ WARN:9@7923.774] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-04-14-a-p0002.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions: 100%|█████████▉| 149720/150000 [2:12:03<00:30,  9.17it/s][ WARN:10@7934.298] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/legaulois-1900-11-22-a-p0014.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions: 100%|█████████▉| 149871/150000 [2:12:20<00:16,  7.80it/s][ WARN:11@7951.230] global loadsave.cpp:268 findDecoder imread_('/scratch/students/danae/data/images/jdpl-1881-02-07-a-p0004.jpg'): can't open/read file: check file path/integrity
# Fetching image dimensions: 100%|██████████| 150000/150000 [2:12:34<00:00, 18.86it/s]

# %%
page_dimensions.sample(5)
# Out:
#                                      file_name  img_height  image_width
# 90399           luxland-1973-02-09-a-p0003.jpg        6425         4252
# 22145           lematin-1886-10-25-a-p0001.jpg        6956         5162
# 35551   lepetitparisien-1903-05-17-a-p0005.jpg        6613         4863
# 65098              jdpl-1935-12-16-a-p0005.jpg        7200         5118
# 125717             jdpl-1826-01-30-a-p0001.jpg        4022         2532

# %%
error_log_df.sample(5)
# Out:
#                             file_name  \
# 530  waeschfra-1873-06-28-a-p0004.jpg
# 687  legaulois-1880-01-31-b-p0004.jpg
# 120  waeschfra-1869-03-27-a-p0001.jpg
# 466  waeschfra-1873-08-10-a-p0001.jpg
# 708       jdpl-1900-06-22-a-p0004.jpg
#
#                                                  error
# 530  Error reading waeschfra-1873-06-28-a-p0004.jpg...
# 687  Error reading legaulois-1880-01-31-b-p0004.jpg...
# 120  Error reading waeschfra-1869-03-27-a-p0001.jpg...
# 466  Error reading waeschfra-1873-08-10-a-p0001.jpg...
# 708  Error reading jdpl-1900-06-22-a-p0004.jpg: Fai...

# %%
# page_dimensions.to_csv("/scratch/students/danae/data/page_dimensions/page_dims_train_large.csv", index=False)
# error_log_df.to_csv("/scratch/students/danae/data/page_dimensions/page_dims_errors_train_large.csv", index=False)

# %%
len(page_dimensions), len(error_log_df), len(page_dimensions)+len(error_log_df)
# Out:
# (149219, 781, 150000)
