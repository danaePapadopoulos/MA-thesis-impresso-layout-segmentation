# %% [markdown]
# # Page Downloading
# This notebook is used to download the pages to the server through requests using the pages' IIF links.

# %%
import os
import time
import shutil
import requests
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

# %%
import dask.dataframe as dd
import pandas as pd
import json
import re

import numpy as np
from tqdm import tqdm
from tqdm.auto import tqdm  # for notebooks

# Create new `pandas` methods which use `tqdm` progress
# (can use tqdm_gui, optional kwargs, etc.)
tqdm.pandas()

import seaborn as sns
import matplotlib.pyplot as plt

from rapidfuzz.distance import Levenshtein

# %%
test_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/test.csv")
train_small_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/train_small.csv")
train_large_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/train_large.csv")

# %%
#pages_df = pd.concat([test_sample, train_small_sample, train_large_sample], ignore_index=True).drop_duplicates(subset="page_id")
pages_df = pd.concat([test_sample, train_small_sample], ignore_index=True).drop_duplicates(subset="page_id")
pages_df["issue_id"] = pages_df["page_id"].apply(lambda x: x.split("-p")[0])
pages_df
# Out:
#                journal                             page_id  \
# 0                 jdpl             jdpl-1814-05-21-a-p0001
# 1                 jdpl             jdpl-1814-05-21-a-p0002
# 2                 jdpl             jdpl-1815-07-05-a-p0001
# 3                 jdpl             jdpl-1815-07-05-a-p0002
# 4                 jdpl             jdpl-1819-01-08-a-p0001
# ...                ...                                 ...
# 54995  lepetitparisien  lepetitparisien-1928-11-24-a-p0009
# 54996             jdpl             jdpl-1836-08-20-a-p0004
# 54997          lematin          lematin-1907-02-06-a-p0004
# 54998           oecaen           oecaen-1924-04-01-a-p0010
# 54999         oerennes         oerennes-1941-01-29-a-p0003
#
#                            issue_id
# 0                 jdpl-1814-05-21-a
# 1                 jdpl-1814-05-21-a
# 2                 jdpl-1815-07-05-a
# 3                 jdpl-1815-07-05-a
# 4                 jdpl-1819-01-08-a
# ...                             ...
# 54995  lepetitparisien-1928-11-24-a
# 54996             jdpl-1836-08-20-a
# 54997          lematin-1907-02-06-a
# 54998           oecaen-1924-04-01-a
# 54999         oerennes-1941-01-29-a
#
# [55000 rows x 3 columns]

# %%
# get journals
journals = pages_df["journal"].sort_values().drop_duplicates().to_list()

# %%
# get image uri for every page of a particular journal collection
uris_df = pd.DataFrame(columns=["page_id", "iiif_img_base_uri"])

for journal in tqdm(journals, desc="Looping through Journals"):
    
    df = pd.read_parquet(f"/scratch/students/danae/data/data_preparation/samples/pages_bbox/{journal}_pages_v2.parquet.gzip", columns=["page_id", "iiif_img_base_uri"]).drop_duplicates()
    uris_df = pd.concat([uris_df, df], ignore_index=True)
    
uris_df
# Out:
# Looping through Journals:   0%|          | 0/36 [00:00<?, ?it/s]
#                              page_id  \
# 0       actionfem-1927-10-15-a-p0001
# 1       actionfem-1927-10-15-a-p0002
# 2       actionfem-1927-10-15-a-p0003
# 3       actionfem-1927-10-15-a-p0004
# 4       actionfem-1927-10-15-a-p0005
# ...                              ...
# 155348  waeschfra-1884-06-14-a-p0004
# 155349  waeschfra-1884-06-28-a-p0001
# 155350  waeschfra-1884-06-28-a-p0002
# 155351  waeschfra-1884-06-28-a-p0003
# 155352  waeschfra-1884-06-28-a-p0004
#
#                                         iiif_img_base_uri
# 0       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 1       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 2       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 3       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 4       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# ...                                                   ...
# 155348  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155349  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155350  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155351  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155352  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
#
# [155353 rows x 2 columns]

# %%
uris_df = uris_df[uris_df["page_id"].isin(pages_df["page_id"])]
uris_df
# Out:
#                              page_id  \
# 8       actionfem-1927-10-15-a-p0009
# 9       actionfem-1927-10-15-a-p0010
# 10      actionfem-1927-10-15-a-p0011
# 11      actionfem-1927-10-15-a-p0012
# 12      actionfem-1927-10-15-a-p0013
# ...                              ...
# 155328  waeschfra-1884-05-10-a-p0004
# 155329  waeschfra-1884-05-17-a-p0001
# 155330  waeschfra-1884-05-17-a-p0002
# 155331  waeschfra-1884-05-17-a-p0003
# 155332  waeschfra-1884-05-17-a-p0004
#
#                                         iiif_img_base_uri
# 8       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 9       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 10      https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 11      https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 12      https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# ...                                                   ...
# 155328  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155329  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155330  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155331  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155332  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
#
# [54999 rows x 2 columns]

# %% [markdown]
# ### Request Image from IIIF Server

# %%
# output dirs
out_dir = "/scratch/students/danae/data"
out_dir_images = os.path.join(out_dir, "images")

os.makedirs(out_dir_images, exist_ok=True)

# %% [markdown]
# ### Get sampled pages

# %%
# add '/full/full/0/default.jpg' to url to get full page
uris_df["iiif_img_base_uri"] = uris_df["iiif_img_base_uri"].apply(lambda x: x + "/full/full/0/default.jpg")
uris_df
# Out:
# /tmp/ipykernel_652057/1384530673.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uris_df["iiif_img_base_uri"] = uris_df["iiif_img_base_uri"].apply(lambda x: x + "/full/full/0/default.jpg")
#                              page_id  \
# 8       actionfem-1927-10-15-a-p0009
# 9       actionfem-1927-10-15-a-p0010
# 10      actionfem-1927-10-15-a-p0011
# 11      actionfem-1927-10-15-a-p0012
# 12      actionfem-1927-10-15-a-p0013
# ...                              ...
# 155328  waeschfra-1884-05-10-a-p0004
# 155329  waeschfra-1884-05-17-a-p0001
# 155330  waeschfra-1884-05-17-a-p0002
# 155331  waeschfra-1884-05-17-a-p0003
# 155332  waeschfra-1884-05-17-a-p0004
#
#                                         iiif_img_base_uri
# 8       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 9       https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 10      https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 11      https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 12      https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# ...                                                   ...
# 155328  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155329  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155330  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155331  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
# 155332  https://iiif.eluxemburgensia.lu/image/iiif/2/a...
#
# [54999 rows x 2 columns]

# %%
import time
import requests
import shutil
from concurrent.futures import ThreadPoolExecutor, as_completed
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %%
def download_iiif_image(iiif_url, f_out, session):
    try:
        with session.get(iiif_url, stream=True) as r:
            if r.status_code == 200:
                r.raw.decode_content = True
                with open(f_out, 'wb') as f:
                    shutil.copyfileobj(r.raw, f)
                return f"Downloaded: {iiif_url}"
            else:
                return f"Failed: {iiif_url} with status {r.status_code}"
    except Exception as e:
        return f"Error: {iiif_url} -> {str(e)}"

# %%
import time

# %%
def download_iiif_image(iiif_url, f_out):
    
    time.sleep(0.5)
    r = requests.get(url, stream=True)
    
    if r.status_code == 200:
        r.raw.decode_content = True
        with open(f_out,'wb') as f:
            shutil.copyfileobj(r.raw, f)
    else:
        print(f"Could not get {iiif_url}")
        
def create_session():
    session = requests.Session()
    retries = Retry(total=5, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
    adapter = HTTPAdapter(max_retries=retries)
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

def download_iiif_image(iiif_url, dest_path, session):
    try:
        with session.get(iiif_url, stream=True) as r:
            if r.status_code == 200:
                r.raw.decode_content = True
                with open(dest_path, 'wb') as f:
                    shutil.copyfileobj(r.raw, f)
                # print(f"Downloaded: {iiif_url}")
            else:
                print(f"Failed: {iiif_url} with status {r.status_code}")
    except Exception as e:
        print(f"Error: {iiif_url} -> {str(e)}")
        time.sleep(60*10)
        

def download_images_sequential(image_urls, page_ids, out_dir_images, delay=0.5):
    session = create_session()
    for iiif_url, page_id in tqdm(zip(image_urls, page_ids), total=len(image_urls), desc="Downloading Images"):
        dest_path = os.path.join(out_dir_images, page_id + ".jpg")
        if not os.path.exists(dest_path):
            print(f"Downloading {iiif_url} -> {dest_path}")
            start = time.time()
            download_iiif_image(iiif_url, dest_path, session)
            end = time.time()
            if (end - start) < 10:
                time.sleep(10)
            else:
                time.sleep(delay)
        else:
            print(f"Skipping {dest_path}, already exists.")

# %%
# output dirs
out_dir = "/scratch/students/danae/data"
out_dir_images = os.path.join(out_dir, "images")

os.makedirs(out_dir_images, exist_ok=True)

# BNF only
df = uris_df[uris_df["iiif_img_base_uri"].str.startswith("https://gallica.bnf")]
# download images
# download_images_parallel
# download_images_sequential
download_images_sequential(image_urls=df["iiif_img_base_uri"], page_ids=df["page_id"], out_dir_images=out_dir_images, delay=1)
# Out:
# Downloading Images:   0%|          | 0/13861 [00:00<?, ?it/s]
# Skipping /scratch/students/danae/data/images/excelsior-1910-11-21-a-p0011.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-11-26-a-p0012.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-11-29-a-p0012.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-01-a-p0007.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-07-a-p0001.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-07-a-p0002.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-07-a-p0003.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-07-a-p0004.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-07-a-p0005.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-07-a-p0006.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-07-a-p0007.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-07-a-p0008.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-08-a-p0009.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-15-a-p0009.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-20-a-p0007.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-21-a-p0001.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-21-a-p0002.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-21-a-p0003.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-21-a-p0004.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-21-a-p0005.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-21-a-p0006.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-21-a-p0008.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-21-a-p0011.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-22-a-p0010.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-26-a-p0012.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-29-a-p0010.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-30-a-p0012.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1910-12-31-a-p0009.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-01-30-a-p0011.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-03-01-a-p0009.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-03-30-a-p0010.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-10-a-p0009.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-12-a-p0001.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-12-a-p0002.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-12-a-p0003.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-12-a-p0004.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-12-a-p0005.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-12-a-p0006.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-12-a-p0007.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-12-a-p0008.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-04-16-a-p0002.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-07-05-a-p0009.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-08-04-a-p0001.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-08-04-a-p0002.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-08-04-a-p0003.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-08-04-a-p0004.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-08-04-a-p0005.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-08-04-a-p0006.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-08-04-a-p0007.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-08-04-a-p0008.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-09-12-a-p0010.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-10-07-a-p0010.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-10-13-a-p0012.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-11-03-a-p0012.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-12-13-a-p0009.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1911-12-22-a-p0010.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-08-a-p0009.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-15-a-p0001.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-15-a-p0002.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-15-a-p0003.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-15-a-p0004.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-15-a-p0005.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-15-a-p0006.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-15-a-p0007.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-01-15-a-p0008.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-02-01-a-p0001.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-02-01-a-p0002.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-02-01-a-p0003.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-02-01-a-p0004.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-02-01-a-p0005.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-02-01-a-p0006.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912-02-01-a-p0007.jpg, already exists.
# Skipping /scratch/students/danae/data/images/excelsior-1912
jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 12
#       8 df = uris_df[uris_df["iiif_img_base_uri"].str.startswith("https://gallica.bnf")]
#       9 # download images
#      10 # download_images_parallel
#      11 # download_images_sequential
# ---> 12 download_images_sequential(image_urls=df["iiif_img_base_uri"], page_ids=df["page_id"], out_dir_images=out_dir_images, delay=1)
#
# Cell In[37], line 43, in download_images_sequential(image_urls, page_ids, out_dir_images, delay)
#      41 print(f"Downloading {iiif_url} -> {dest_path}")
#      42 start = time.time()
# ---> 43 download_iiif_image(iiif_url, dest_path, session)
#      44 end = time.time()
#      45 if (end - start) < 10:
#
# Cell In[37], line 27, in download_iiif_image(iiif_url, dest_path, session)
#      25     r.raw.decode_content = True
#      26     with open(dest_path, 'wb') as f:
# ---> 27         shutil.copyfileobj(r.raw, f)
#      28     # print(f"Downloaded: {iiif_url}")
#      29 else:
#      30     print(f"Failed: {iiif_url} with status {r.status_code}")
#
# File /scratch/students/danae/.conda/envs/layout_seg/lib/python3.12/shutil.py:203, in copyfileobj(fsrc, fdst, length)
#     201 fsrc_read = fsrc.read
#     202 fdst_write = fdst.write
# --> 203 while buf := fsrc_read(length):
#     204     fdst_write(buf)
#
# File /scratch/students/danae/.conda/envs/layout_seg/lib/python3.12/site-packages/urllib3/response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File /scratch/students/danae/.conda/envs/layout_seg/lib/python3.12/site-packages/urllib3/response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File /scratch/students/danae/.conda/envs/layout_seg/lib/python3.12/site-packages/urllib3/response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /scratch/students/danae/.conda/envs/layout_seg/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /scratch/students/danae/.conda/envs/layout_seg/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /scratch/students/danae/.conda/envs/layout_seg/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /scratch/students/danae/.conda/envs/layout_seg/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
