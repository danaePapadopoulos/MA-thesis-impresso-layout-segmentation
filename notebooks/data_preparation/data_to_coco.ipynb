# %% [markdown]
# # Convert Data into COCO format

# %%
import os
import re
import cv2
import json

import numpy as np
import pandas as pd

from joblib import Parallel, delayed

from tqdm import tqdm
from tqdm.auto import tqdm  # for notebooks
tqdm.pandas()

# %% [markdown]
# ## Read and Split Data

# %%
## get Splits (train - small or large - vs test)
test_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/test.csv")
train_small_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/train_small.csv")
train_large_sample = pd.read_csv("/scratch/students/danae/data/data_preparation/samples/pages/train_large.csv")

# %%
## read labelled data
data = pd.read_parquet("/scratch/students/danae/data/modelling_data/data.parquet.gzip")

# %%
# get pages of splits
pages_test = test_sample["page_id"].drop_duplicates()
print(len(pages_test))

pages_train_small = train_small_sample["page_id"].drop_duplicates()
print(len(pages_train_small))

pages_train_large = train_large_sample["page_id"].drop_duplicates()
print(len(pages_train_large))
# Out:
# 5000
# 50000
# 150000

# %%
# split the dataset containing bbox labels
data_test = data[data["page_id"].isin(pages_test)]
pages_test = data_test["page_id"].drop_duplicates()
print(len(pages_test))

data_train_small = data[data["page_id"].isin(pages_train_small)]
pages_train_small = data_train_small["page_id"].drop_duplicates()
print(len(pages_train_small))

data_train_large = data[data["page_id"].isin(pages_train_large)]
pages_train_large = data_train_large["page_id"].drop_duplicates()
print(len(pages_train_large))
# Out:
# 4109
# 41302
# 123408

# %%
# create train-validation splits
validation_prop = 0.2

# small
pages_validation_small = pages_train_small.sample(frac=validation_prop, replace=False).to_list()
pages_train_small = [p for p in pages_train_small if p not in pages_validation_small]
print(len(pages_validation_small)), print(len(pages_train_small)), print(len(pages_validation_small) + len(pages_train_small))

# large
pages_validation_large = pages_train_large.sample(frac=validation_prop, replace=False).to_list()
pages_train_large = [p for p in pages_train_large if p not in pages_validation_large]
print(len(pages_validation_large)), print(len(pages_train_large)), print(len(pages_validation_large) + len(pages_train_large))
# Out:
# 8260
# 33042
# 41302
# 24682
# 98726
# 123408
# (None, None, None)

# %% [markdown]
# ## Convert to COCO

# %%
# pages_test
# pages_train_small, pages_validation_small
# pages_train_large, pages_validation_large

# %%
coco_fn = "coco_annotations_test"

coco_df = data[data["page_id"].isin(pages_test)][["page_id", "journal", "iiif_img_base_uri", "bbx_paragraph", "lines_tokens", "ci_id", "ci_tp"]].reset_index(drop=True)
len(coco_df)
# Out:
# 84375

# %%
coco_df["supercategory"] = coco_df["ci_tp"]
coco_df = coco_df.rename(
    columns={"ci_tp": "category", "bbx_paragraph": "bbox"}
)

# %%
# set page ids
page_ids_df = coco_df[["page_id"]].drop_duplicates().reset_index(drop=True)
page_ids_df["id"] = page_ids_df.index
page_ids_df.head(5)
# Out:
#                         page_id  id
# 0  actionfem-1930-01-15-a-p0009   0
# 1  actionfem-1930-10-15-a-p0012   1
# 2  actionfem-1931-08-15-a-p0017   2
# 3  actionfem-1932-12-15-a-p0014   3
# 4  actionfem-1933-09-15-a-p0010   4

# %%
# set category ids
category_ids_df = coco_df[["category"]].drop_duplicates().reset_index(drop=True)
category_ids_df["id"] = category_ids_df.index
category_ids_df
# Out:
#         category  id
# 0  article_title   0
# 1   death_notice   1
# 2          table   2
# 3          image   3
# 4  image_caption   4
# 5             ad   5
# 6        weather   6
# 7        article   7
# 8       earrings   8

# %%
dims_df = pd.read_csv("/scratch/students/danae/data/page_dimensions/page_dims_test.csv") ####### Carefull if not test !!!
dims_df
# Out:
#                                    file_name  img_height  image_width
# 0                jdpl-1815-07-05-a-p0001.jpg        3936         2473
# 1                jdpl-1820-07-08-a-p0002.jpg        3993         2572
# 2                jdpl-1823-02-12-a-p0003.jpg        3998         2581
# 3                jdpl-1823-02-08-a-p0002.jpg        3995         2587
# 4                jdpl-1821-10-28-a-p0002.jpg        3994         2535
# ...                                      ...         ...          ...
# 4975         indeplux-1875-10-22-a-p0002.jpg        5711         3944
# 4976  lepetitparisien-1922-04-17-a-p0002.jpg        6855         4957
# 4977         indeplux-1924-08-28-a-p0002.jpg        6767         4711
# 4978  lepetitparisien-1906-08-26-a-p0004.jpg        6827         4899
# 4979           oeuvre-1922-10-31-a-p0006.jpg        8628         5998
#
# [4980 rows x 3 columns]

# %%
# get dimensions of images
images_df = page_ids_df.merge(data[["page_id", "iiif_img_base_uri"]], on="page_id")
images_df = images_df.rename(columns={"page_id": "file_name"})
images_df["iiif_img_base_uri"] = images_df["iiif_img_base_uri"].apply(lambda x: x+"/full/full/0/default.jpg")
images_df["file_name"] = images_df["file_name"].apply(lambda x: x+".jpg")

dims_test_df = pd.read_csv("/scratch/students/danae/data/page_dimensions/page_dims_test.csv")
dims_train_small_df = pd.read_csv("/scratch/students/danae/data/page_dimensions/page_dims_train_small.csv")
dims_train_large_df = pd.read_csv("/scratch/students/danae/data/page_dimensions/page_dims_train_large.csv")

dims_df = pd.concat([dims_test_df, dims_train_small_df, dims_train_large_df]).drop_duplicates()
print(len(dims_df))

images_df = pd.merge(dims_df, images_df, on="file_name")
images_df = images_df.drop(columns=["iiif_img_base_uri"])
# images_df = images_df.drop(columns=["file_name"])
# images_df = images_df.rename(columns={"iiif_img_base_uri": "file_name"})
images_df = images_df.drop_duplicates()
images_df
# Out:
# 154551
#                                     file_name  img_height  image_width    id
# 0                 jdpl-1815-07-05-a-p0001.jpg        3936         2473   494
# 8                 jdpl-1820-07-08-a-p0002.jpg        3993         2572   496
# 15                jdpl-1823-02-12-a-p0003.jpg        3998         2581   499
# 20                jdpl-1823-02-08-a-p0002.jpg        3995         2587   498
# 25                jdpl-1821-10-28-a-p0002.jpg        3994         2535  3962
# ...                                       ...         ...          ...   ...
# 84010      courriergdl-1857-02-13-a-p0003.jpg        4795         3260   188
# 84021         indeplux-1875-10-22-a-p0002.jpg        5711         3944   348
# 84036  lepetitparisien-1922-04-17-a-p0002.jpg        6855         4957  1084
# 84089  lepetitparisien-1906-08-26-a-p0004.jpg        6827         4899  1061
# 84145           oeuvre-1922-10-31-a-p0006.jpg        8628         5998  3389
#
# [4091 rows x 4 columns]

# %%
# process unique categories
categories_df = coco_df[["supercategory", "category"]]
categories_df = categories_df.merge(category_ids_df, on="category").drop_duplicates()
categories_df = categories_df.rename(
    columns={"category": "name"}
)

categories_df
# Out:
#        supercategory           name  id
# 0      article_title  article_title   0
# 622     death_notice   death_notice   1
# 19580          table          table   2
# 20456          image          image   3
# 20457  image_caption  image_caption   4
# 21166             ad             ad   5
# 28104        weather        weather   6
# 28109        article        article   7
# 81471       earrings       earrings   8

# %%
# create a mapping from page_id to id
page_to_id = dict(zip(page_ids_df["page_id"], page_ids_df["id"]))

# create a mapping from category to id
category_to_id = dict(zip(category_ids_df["category"], category_ids_df["id"]))

# generate annotations in parallel
annotations_df = coco_df[["page_id", "category", "bbox"]]

# map "page_id" and "category" to ids using the mapping
annotations_df["image_id"] = annotations_df["page_id"].map(page_to_id)
annotations_df["category_id"] = annotations_df["category"].map(category_to_id)
annotations_df["area"] = annotations_df["bbox"].apply(lambda x: x[2] * x[3])  # width * height
annotations_df["iscrowd"] = 0
annotations_df["id"] = range(1, len(annotations_df) + 1) # to check
annotations_df["bbox"] = annotations_df["bbox"].map(list) #.astype(str) # array to list
annotations_df["segmentation"] = annotations_df["bbox"].apply(lambda x: [[x[0], x[1], x[0]+x[2], x[1], x[0]+x[2], x[1]+x[3], x[0], x[1]+x[3]]]).map(list) #.astype(str) # array to list

annotations_df = annotations_df.drop(columns=["page_id", "category"])
annotations_df.sample(3)
# Out:
# /tmp/ipykernel_2081383/218450434.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   annotations_df["image_id"] = annotations_df["page_id"].map(page_to_id)
# /tmp/ipykernel_2081383/218450434.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   annotations_df["category_id"] = annotations_df["category"].map(category_to_id)
# /tmp/ipykernel_2081383/218450434.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   annotations_df["area"] = annotations_df["bbox"].apply(lambda x: x[2] * x[3])  # width * height
# /tmp/ipykernel_2081383/218450434.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   annotations_df["iscrowd"] = 0
#                           bbox  image_id  category_id    area  iscrowd     id  \
# 83491       [89, 94, 3292, 78]      2322            8  256776        0  83492
# 4717   [3131, 1863, 1158, 163]       743            0  188754        0   4718
# 25654   [2972, 1422, 429, 327]      1887            5  140283        0  25655
#
#                                             segmentation
# 83491           [[89, 94, 3381, 94, 3381, 172, 89, 172]]
# 4717   [[3131, 1863, 4289, 1863, 4289, 2026, 3131, 20...
# 25654  [[2972, 1422, 3401, 1422, 3401, 1749, 2972, 17...

# %%
coco_format = {
    "images": images_df.to_dict(orient="records"),
    "annotations": annotations_df.to_dict(orient="records"),
    "categories": categories_df.to_dict(orient="records"),
}
coco_format
# Out:
# {'images': [{'file_name': 'jdpl-1815-07-05-a-p0001.jpg',
#    'img_height': 3936,
#    'image_width': 2473,
#    'id': 494},
#   {'file_name': 'jdpl-1820-07-08-a-p0002.jpg',
#    'img_height': 3993,
#    'image_width': 2572,
#    'id': 496},
#   {'file_name': 'jdpl-1823-02-12-a-p0003.jpg',
#    'img_height': 3998,
#    'image_width': 2581,
#    'id': 499},
#   {'file_name': 'jdpl-1823-02-08-a-p0002.jpg',
#    'img_height': 3995,
#    'image_width': 2587,
#    'id': 498},
#   {'file_name': 'jdpl-1821-10-28-a-p0002.jpg',
#    'img_height': 3994,
#    'image_width': 2535,
#    'id': 3962},
#   {'file_name': 'jdpl-1814-05-21-a-p0002.jpg',
#    'img_height': 3960,
#    'image_width': 2454,
#    'id': 493},
#   {'file_name': 'jdpl-1819-01-08-a-p0002.jpg',
#    'img_height': 4000,
#    'image_width': 2428,
#    'id': 3961},
#   {'file_name': 'jdpl-1823-02-12-a-p0004.jpg',
#    'img_height': 3995,
#    'image_width': 2586,
#    'id': 500},
#   {'file_name': 'jdpl-1819-01-08-a-p0001.jpg',
#    'img_height': 3999,
#    'image_width': 2437,
#    'id': 495},
#   {'file_name': 'jdpl-1824-01-13-a-p0001.jpg',
#    'img_height': 4034,
#    'image_width': 2532,
#    'id': 501},
#   {'file_name': 'jdpl-1821-10-28-a-p0001.jpg',
#    'img_height': 3993,
#    'image_width': 2529,
#    'id': 497},
#   {'file_name': 'jdpl-1815-07-05-a-p0002.jpg',
#    'img_height': 3932,
#    'image_width': 2453,
#    'id': 3960},
#   {'file_name': 'jdpl-1814-05-21-a-p0001.jpg',
#    'img_height': 3935,
#    'image_width': 2438,
#    'id': 492},
#   {'file_name': 'jdpl-1826-10-18-a-p0003.jpg',
#    'img_height': 4023,
#    'image_width': 2545,
#    'id': 508},
#   {'file_name': 'jdpl-1826-10-18-a-p0002.jpg',
#    'img_height': 4015,
#    'image_width': 2550,
#    'id': 507},
#   {'file_name': 'jdpl-1826-10-18-a-p0001.jpg',
#    'img_height': 4041,
#    'image_width': 2553,
#    'id': 506},
#   {'file_name': 'jdpl-1824-05-12-a-p0004.jpg',
#    'img_height': 4028,
#    'image_width': 2551,
#    'id': 504},
#   {'file_name': 'jdpl-1827-06-04-a-p0003.jpg',
#    'img_height': 4031,
#    'image_width': 2542,
#    'id': 512},
#   {'file_name': 'jdpl-1827-03-25-a-p0002.jpg',
#    'img_height': 4035,
#    'image_width': 2580,
#    'id': 511},
#   {'file_name': 'jdpl-1827-03-25-a-p0001.jpg',
#    'img_height': 4041,
#    'image_width': 2567,
#    'id': 510},
#   {'file_name': 'jdpl-1824-01-13-a-p0002.jpg',
#    'img_height': 4038,
#    'image_width': 2536,
#    'id': 502},
#   {'file_name': 'jdpl-1824-05-12-a-p0003.jpg',
#    'img_height': 4005,
#    'image_width': 2549,
#    'id': 503},
#   {'file_name': 'jdpl-1826-10-18-a-p0004.jpg',
#    'img_height': 4025,
#    'image_width': 2568,
#    'id': 509},
#   {'file_name': 'jdpl-1828-04-28-a-p0001.jpg',
#    'img_height': 4393,
#    'image_width': 3596,
#    'id': 513},
#   {'file_name': 'jdpl-1828-04-28-a-p0002.jpg',
#    'img_height': 4396,
#    'image_width': 3588,
#    'id': 514},
#   {'file_name': 'jdpl-1828-04-29-a-p0004.jpg',
#    'img_height': 4415,
#    'image_width': 3626,
#    'id': 515},
#   {'file_name': 'jdpl-1828-04-29-a-p0003.jpg',
#    'img_height': 4389,
#    'image_width': 3579,
#    'id': 3685},
#   {'file_name': 'jdpl-1829-07-15-a-p0002.jpg',
#    'img_height': 4383,
#    'image_width': 3580,
#    'id': 516},
#   {'file_name': 'jdpl-1829-07-15-a-p0004.jpg',
#    'img_height': 4429,
#    'image_width': 3623,
#    'id': 517},
#   {'file_name': 'jdpl-1829-07-15-a-p0003.jpg',
#    'img_height': 4412,
#    'image_width': 3627,
#    'id': 3686},
#   {'file_name': 'jdpl-1830-11-26-a-p0004.jpg',
#    'img_height': 5098,
#    'image_width': 3753,
#    'id': 518},
#   {'file_name': 'jdpl-1830-11-27-a-p0002.jpg',
#    'img_height': 5068,
#    'image_width': 3776,
#    'id': 519},
#   {'file_name': 'jdpl-1831-08-04-a-p0002.jpg',
#    'img_height': 5075,
#    'image_width': 3763,
#    'id': 522},
#   {'file_name': 'jdpl-1831-05-06-a-p0003.jpg',
#    'img_height': 5057,
#    'image_width': 3773,
#    'id': 520},
#   {'file_name': 'jdpl-1830-11-26-a-p0003.jpg',
#    'img_height': 5062,
#    'image_width': 3722,
#    'id': 3963},
#   {'file_name': 'jdpl-1832-05-05-a-p0002.jpg',
#    'img_height': 5082,
#    'image_width': 3703,
#    'id': 3965},
#   {'file_name': 'jdpl-1832-05-05-a-p0001.jpg',
#    'img_height': 5064,
#    'image_width': 3703,
#    'id': 524},
#   {'file_name': 'jdpl-1832-01-19-a-p0004.jpg',
#    'img_height': 5090,
#    'image_width': 3694,
#    'id': 523},
#   {'file_name': 'jdpl-1831-05-06-a-p0004.jpg',
#    'img_height': 5059,
#    'image_width': 3774,
#    'id': 521},
#   {'file_name': 'jdpl-1832-01-19-a-p0003.jpg',
#    'img_height': 5094,
#    'image_width': 3730,
#    'id': 3964},
#   {'file_name': 'jdpl-1833-06-19-a-p0001.jpg',
#    'img_height': 5117,
#    'image_width': 3701,
#    'id': 525},
#   {'file_name': 'jdpl-1833-06-19-a-p0002.jpg',
#    'img_height': 5091,
#    'image_width': 3722,
#    'id': 526},
#   {'file_name': 'jdpl-1833-06-19-a-p0003.jpg',
#    'img_height': 5103,
#    'image_width': 3705,
#    'id': 3966},
#   {'file_name': 'jdpl-1833-06-19-a-p0004.jpg',
#    'img_height': 5107,
#    'image_width': 3718,
#    'id': 527},
#   {'file_name': 'jdpl-1835-08-02-a-p0002.jpg',
#    'img_height': 5129,
#    'image_width': 3715,
#    'id': 3967},
#   {'file_name': 'jdpl-1834-09-16-a-p0002.jpg',
#    'img_height': 5138,
#    'image_width': 3811,
#    'id': 529},
#   {'file_name': 'jdpl-1834-09-16-a-p0004.jpg',
#    'img_height': 5171,
#    'image_width': 3858,
#    'id': 531},
#   {'file_name': 'jdpl-1834-09-16-a-p0003.jpg',
#    'img_height': 5182,
#    'image_width': 3845,
#    'id': 530},
#   {'file_name': 'jdpl-1836-12-09-a-p0001.jpg',
#    'img_height': 5024,
#    'image_width': 3762,
#    'id': 534},
#   {'file_name': 'jdpl-1835-08-04-a-p0003.jpg',
#    'img_height': 5135,
#    'image_width': 3715,
#    'id': 533},
#   {'file_name': 'jdpl-1836-12-09-a-p0003.jpg',
#    'img_height': 5014,
#    'image_width': 3749,
#    'id': 535},
#   {'file_name': 'jdpl-1836-12-09-a-p0002.jpg',
#    'img_height': 5030,
#    'image_width': 3777,
#    'id': 3968},
#   {'file_name': 'jdpl-1836-12-09-a-p0004.jpg',
#    'img_height': 5020,
#    'image_width': 3754,
#    'id': 536},
#   {'file_name': 'jdpl-1838-06-11-a-p0003.jpg',
#    'img_height': 6490,
#    'image_width': 4427,
#    'id': 542},
#   {'file_name': 'jdpl-1837-06-11-a-p0001.jpg',
#    'img_height': 6663,
#    'image_width': 4358,
#    'id': 537},
#   {'file_name': 'jdpl-1837-06-11-a-p0003.jpg',
#    'img_height': 6691,
#    'image_width': 4400,
#    'id': 539},
#   {'file_name': 'jdpl-1838-06-11-a-p0004.jpg',
#    'img_height': 6460,
#    'image_width': 4405,
#    'id': 543},
#   {'file_name': 'jdpl-1837-06-11-a-p0002.jpg',
#    'img_height': 6617,
#    'image_width': 4445,
#    'id': 538},
#   {'file_name': 'jdpl-1839-07-02-a-p0004.jpg',
#    'img_height': 6363,
#    'image_width': 4332,
#    'id': 545},
#   {'file_name': 'jdpl-1839-07-02-a-p0002.jpg',
#    'img_height': 6369,
#    'image_width': 4317,
#    'id': 544},
#   {'file_name': 'jdpl-1838-06-11-a-p0002.jpg',
#    'img_height': 6536,
#    'image_width': 4407,
#    'id': 541},
#   {'file_name': 'diekwochen-1841-08-21-a-p0001.jpg',
#    'img_height': 3768,
#    'image_width': 2563,
#    'id': 287},
#   {'file_name': 'diekwochen-1841-08-21-a-p0002.jpg',
#    'img_height': 3768,
#    'image_width': 2563,
#    'id': 288},
#   {'file_name': 'diekwochen-1841-01-09-a-p0003.jpg',
#    'img_height': 4063,
#    'image_width': 2752,
#    'id': 286},
#   {'file_name': 'jdpl-1839-07-02-a-p0003.jpg',
#    'img_height': 6371,
#    'image_width': 4335,
#    'id': 3969},
#   {'file_name': 'diekwochen-1842-06-11-a-p0003.jpg',
#    'img_height': 3685,
#    'image_width': 2598,
#    'id': 289},
#   {'file_name': 'jdpl-1840-05-19-a-p0003.jpg',
#    'img_height': 6319,
#    'image_width': 4330,
#    'id': 547},
#   {'file_name': 'diekwochen-1842-06-11-a-p0002.jpg',
#    'img_height': 3685,
#    'image_width': 2598,
#    'id': 3958},
#   {'file_name': 'diekwochen-1843-11-18-a-p0001.jpg',
#    'img_height': 3720,
#    'image_width': 2528,
#    'id': 290},
#   {'file_name': 'diekwochen-1843-11-18-a-p0002.jpg',
#    'img_height': 3720,
#    'image_width': 2528,
#    'id': 291},
#   {'file_name': 'jdpl-1840-05-19-a-p0002.jpg',
#    'img_height': 6373,
#    'image_width': 4369,
#    'id': 546},
#   {'file_name': 'courriergdl-1849-08-11-a-p0001.jpg',
#    'img_height': 4475,
#    'image_width': 2963,
#    'id': 157},
#   {'file_name': 'courriergdl-1849-08-11-a-p0003.jpg',
#    'img_height': 4475,
#    'image_width': 2963,
#    'id': 159},
#   {'file_name': 'luxwort-1849-10-24-a-p0001.jpg',
#    'img_height': 4323,
#    'image_width': 2870,
#    'id': 2842},
#   {'file_name': 'courriergdl-1849-08-11-a-p0002.jpg',
#    'img_height': 4475,
#    'image_width': 2963,
#    'id': 158},
#   {'file_name': 'courriergdl-1849-08-11-a-p0004.jpg',
#    'img_height': 4475,
#    'image_width': 2963,
#    'id': 160},
#   {'file_name': 'luxwort-1849-10-24-a-p0004.jpg',
#    'img_height': 4323,
#    'image_width': 2870,
#    'id': 2845},
#   {'file_name': 'luxwort-1849-10-24-a-p0002.jpg',
#    'img_height': 4323,
#    'image_width': 2870,
#    'id': 2843},
#   {'file_name': 'courriergdl-1850-10-26-a-p0001.jpg',
#    'img_height': 4429,
#    'image_width': 2965,
#    'id': 161},
#   {'file_name': 'luxwort-1849-10-24-a-p0003.jpg',
#    'img_height': 4323,
#    'image_width': 2870,
#    'id': 2844},
#   {'file_name': 'courriergdl-1850-10-26-a-p0004.jpg',
#    'img_height': 4429,
#    'image_width': 2965,
#    'id': 163},
#   {'file_name': 'courriergdl-1850-10-26-a-p0003.jpg',
#    'img_height': 4429,
#    'image_width': 2965,
#    'id': 162},
#   {'file_name': 'courriergdl-1850-10-26-a-p0002.jpg',
#    'img_height': 4429,
#    'image_width': 2965,
#    'id': 3951},
#   {'file_name': 'luxwort-1850-09-25-a-p0001.jpg',
#    'img_height': 4346,
#    'image_width': 2941,
#    'id': 2848},
#   {'file_name': 'jdpl-1840-05-19-a-p0004.jpg',
#    'img_height': 6339,
#    'image_width': 4336,
#    'id': 3687},
#   {'file_name': 'luxwort-1850-07-07-a-p0002.jpg',
#    'img_height': 4417,
#    'image_width': 2988,
#    'id': 2846},
#   {'file_name': 'courriergdl-1851-05-28-a-p0001.jpg',
#    'img_height': 4453,
#    'image_width': 2965,
#    'id': 164},
#   {'file_name': 'courriergdl-1851-05-28-a-p0002.jpg',
#    'img_height': 4453,
#    'image_width': 2965,
#    'id': 165},
#   {'file_name': 'luxwort-1850-09-13-a-p0003.jpg',
#    'img_height': 4358,
#    'image_width': 2953,
#    'id': 2847},
#   {'file_name': 'courriergdl-1851-10-18-a-p0004.jpg',
#    'img_height': 4465,
#    'image_width': 2976,
#    'id': 167},
#   {'file_name': 'courriergdl-1851-10-18-a-p0003.jpg',
#    'img_height': 4465,
#    'image_width': 2976,
#    'id': 166},
#   {'file_name': 'luxwort-1851-10-22-a-p0001.jpg',
#    'img_height': 4406,
#    'image_width': 2965,
#    'id': 2850},
#   {'file_name': 'jdpl-1843-05-26-a-p0002.jpg',
#    'img_height': 6319,
#    'image_width': 4327,
#    'id': 3970},
#   {'file_name': 'luxwort-1851-10-22-a-p0002.jpg',
#    'img_height': 4406,
#    'image_width': 2965,
#    'id': 2851},
#   {'file_name': 'courriergdl-1852-08-28-a-p0001.jpg',
#    'img_height': 4512,
#    'image_width': 3094,
#    'id': 168},
#   {'file_name': 'luxwort-1851-06-04-a-p0003.jpg',
#    'img_height': 4505,
#    'image_width': 2955,
#    'id': 2849},
#   {'file_name': 'courriergdl-1852-08-28-a-p0002.jpg',
#    'img_height': 4512,
#    'image_width': 3094,
#    'id': 3952},
#   {'file_name': 'luxwort-1852-05-09-a-p0002.jpg',
#    'img_height': 4323,
#    'image_width': 2941,
#    'id': 2852},
#   {'file_name': 'courriergdl-1852-08-28-a-p0004.jpg',
#    'img_height': 4512,
#    'image_width': 3094,
#    'id': 170},
#   {'file_name': 'courriergdl-1852-08-28-a-p0003.jpg',
#    'img_height': 4512,
#    'image_width': 3094,
#    'id': 169},
#   {'file_name': 'luxwort-1852-09-10-a-p0003.jpg',
#    'img_height': 4323,
#    'image_width': 2929,
#    'id': 2853},
#   {'file_name': 'luxwort-1852-09-10-a-p0004.jpg',
#    'img_height': 4323,
#    'image_width': 2929,
#    'id': 2854},
#   {'file_name': 'waechtersauer-1852-03-20-a-p0002.jpg',
#    'img_height': 4583,
#    'image_width': 3071,
#    'id': 3459},
#   {'file_name': 'waechtersauer-1852-03-20-a-p0001.jpg',
#    'img_height': 4583,
#    'image_width': 3071,
#    'id': 3458},
#   {'file_name': 'waechtersauer-1852-03-20-a-p0003.jpg',
#    'img_height': 4583,
#    'image_width': 3071,
#    'id': 3460},
#   {'file_name': 'waechtersauer-1852-03-20-a-p0004.jpg',
#    'img_height': 4583,
#    'image_width': 3071,
#    'id': 3461},
#   {'file_name': 'courriergdl-1853-08-06-a-p0002.jpg',
#    'img_height': 4500,
#    'image_width': 3142,
#    'id': 3953},
#   {'file_name': 'courriergdl-1853-08-06-a-p0001.jpg',
#    'img_height': 4500,
#    'image_width': 3142,
#    'id': 172},
#   {'file_name': 'courriergdl-1853-08-06-a-p0003.jpg',
#    'img_height': 4500,
#    'image_width': 3142,
#    'id': 173},
#   {'file_name': 'luxwort-1853-12-21-a-p0001.jpg',
#    'img_height': 4299,
#    'image_width': 2894,
#    'id': 2855},
#   {'file_name': 'courriergdl-1853-11-02-a-p0004.jpg',
#    'img_height': 4500,
#    'image_width': 3083,
#    'id': 174},
#   {'file_name': 'luxwort-1853-12-21-a-p0002.jpg',
#    'img_height': 4299,
#    'image_width': 2894,
#    'id': 2856},
#   {'file_name': 'luxwort-1853-12-21-a-p0004.jpg',
#    'img_height': 4299,
#    'image_width': 2894,
#    'id': 2858},
#   {'file_name': 'luxwort-1853-12-21-a-p0003.jpg',
#    'img_height': 4299,
#    'image_width': 2894,
#    'id': 2857},
#   {'file_name': 'waechtersauer-1853-05-07-a-p0001.jpg',
#    'img_height': 4476,
#    'image_width': 3142,
#    'id': 3462},
#   {'file_name': 'waechtersauer-1853-05-07-a-p0002.jpg',
#    'img_height': 4476,
#    'image_width': 3142,
#    'id': 3463},
#   {'file_name': 'waechtersauer-1853-05-07-a-p0003.jpg',
#    'img_height': 4476,
#    'image_width': 3142,
#    'id': 3464},
#   {'file_name': 'waechtersauer-1853-05-07-a-p0004.jpg',
#    'img_height': 4476,
#    'image_width': 3142,
#    'id': 3465},
#   {'file_name': 'courriergdl-1854-04-22-a-p0001.jpg',
#    'img_height': 4441,
#    'image_width': 3059,
#    'id': 175},
#   {'file_name': 'courriergdl-1854-04-22-a-p0002.jpg',
#    'img_height': 4441,
#    'image_width': 3059,
#    'id': 176},
#   {'file_name': 'courriergdl-1854-04-22-a-p0003.jpg',
#    'img_height': 4441,
#    'image_width': 3059,
#    'id': 177},
#   {'file_name': 'courriergdl-1854-04-22-a-p0004.jpg',
#    'img_height': 4441,
#    'image_width': 3059,
#    'id': 3615},
#   {'file_name': 'luxwort-1854-09-03-a-p0001.jpg',
#    'img_height': 4299,
#    'image_width': 2929,
#    'id': 2861},
#   {'file_name': 'luxwort-1854-09-03-a-p0002.jpg',
#    'img_height': 4299,
#    'image_width': 2929,
#    'id': 2862},
#   {'file_name': 'luxwort-1854-03-08-a-p0004.jpg',
#    'img_height': 4311,
#    'image_width': 2906,
#    'id': 2860},
#   {'file_name': 'waechtersauer-1854-02-22-a-p0002.jpg',
#    'img_height': 4358,
#    'image_width': 3083,
#    'id': 3466},
#   {'file_name': 'luxwort-1854-03-08-a-p0003.jpg',
#    'img_height': 4311,
#    'image_width': 2906,
#    'id': 2859},
#   {'file_name': 'waechtersauer-1854-02-22-a-p0004.jpg',
#    'img_height': 4358,
#    'image_width': 3083,
#    'id': 3468},
#   {'file_name': 'waechtersauer-1854-02-22-a-p0003.jpg',
#    'img_height': 4358,
#    'image_width': 3083,
#    'id': 3467},
#   {'file_name': 'courriergdl-1855-04-25-a-p0001.jpg',
#    'img_height': 4453,
#    'image_width': 2976,
#    'id': 178},
#   {'file_name': 'courriergdl-1855-04-25-a-p0003.jpg',
#    'img_height': 4453,
#    'image_width': 2976,
#    'id': 180},
#   {'file_name': 'courriergdl-1855-04-25-a-p0002.jpg',
#    'img_height': 4453,
#    'image_width': 2976,
#    'id': 179},
#   {'file_name': 'courriergdl-1855-04-25-a-p0004.jpg',
#    'img_height': 4453,
#    'image_width': 2976,
#    'id': 181},
#   {'file_name': 'luxwort-1855-03-28-a-p0001.jpg',
#    'img_height': 4346,
#    'image_width': 2976,
#    'id': 2864},
#   {'file_name': 'luxwort-1855-03-28-a-p0002.jpg',
#    'img_height': 4346,
#    'image_width': 2976,
#    'id': 2865},
#   {'file_name': 'waechtersauer-1855-11-24-a-p0001.jpg',
#    'img_height': 4453,
#    'image_width': 3047,
#    'id': 3470},
#   {'file_name': 'jdpl-1852-10-29-a-p0001.jpg',
#    'img_height': 7193,
#    'image_width': 5039,
#    'id': 553},
#   {'file_name': 'waechtersauer-1855-11-21-a-p0003.jpg',
#    'img_height': 4453,
#    'image_width': 3047,
#    'id': 3469},
#   {'file_name': 'jdpl-1852-10-29-a-p0002.jpg',
#    'img_height': 7193,
#    'image_width': 5028,
#    'id': 554},
#   {'file_name': 'waechtersauer-1855-11-24-a-p0002.jpg',
#    'img_height': 4453,
#    'image_width': 3047,
#    'id': 4104},
#   {'file_name': 'waechtersauer-1855-11-21-a-p0004.jpg',
#    'img_height': 4453,
#    'image_width': 3047,
#    'id': 3940},
#   {'file_name': 'courriergdl-1856-12-18-a-p0002.jpg',
#    'img_height': 4512,
#    'image_width': 3106,
#    'id': 183},
#   {'file_name': 'luxwort-1855-10-28-a-p0003.jpg',
#    'img_height': 4346,
#    'image_width': 2954,
#    'id': 2866},
#   {'file_name': 'courriergdl-1856-12-18-a-p0003.jpg',
#    'img_height': 4512,
#    'image_width': 3106,
#    'id': 184},
#   {'file_name': 'courriergdl-1856-12-18-a-p0004.jpg',
#    'img_height': 4512,
#    'image_width': 3106,
#    'id': 185},
#   {'file_name': 'courriergdl-1856-12-18-a-p0001.jpg',
#    'img_height': 4512,
#    'image_width': 3106,
#    'id': 182},
#   {'file_name': 'luxwort-1856-02-03-a-p0001.jpg',
#    'img_height': 4335,
#    'image_width': 2917,
#    'id': 2867},
#   {'file_name': 'luxwort-1856-05-09-a-p0004.jpg',
#    'img_height': 4394,
#    'image_width': 2906,
#    'id': 2870},
#   {'file_name': 'luxwort-1856-02-03-a-p0002.jpg',
#    'img_height': 4335,
#    'image_width': 2917,
#    'id': 2868},
#   {'file_name': 'waechtersauer-1856-10-29-a-p0001.jpg',
#    'img_height': 4488,
#    'image_width': 3130,
#    'id': 3471},
#   {'file_name': 'luxwort-1856-05-09-a-p0003.jpg',
#    'img_height': 4394,
#    'image_width': 2906,
#    'id': 2869},
#   {'file_name': 'waechtersauer-1856-10-29-a-p0004.jpg',
#    'img_height': 4488,
#    'image_width': 3130,
#    'id': 3941},
#   {'file_name': 'waechtersauer-1856-10-29-a-p0002.jpg',
#    'img_height': 4488,
#    'image_width': 3130,
#    'id': 4105},
#   {'file_name': 'waechtersauer-1856-10-29-a-p0003.jpg',
#    'img_height': 4488,
#    'image_width': 3130,
#    'id': 4106},
#   {'file_name': 'courriergdl-1857-07-17-a-p0002.jpg',
#    'img_height': 4807,
#    'image_width': 3201,
#    'id': 3954},
#   {'file_name': 'courriergdl-1857-07-17-a-p0001.jpg',
#    'img_height': 4807,
#    'image_width': 3201,
#    'id': 189},
#   {'file_name': 'courriergdl-1857-01-18-a-p0003.jpg',
#    'img_height': 4772,
#    'image_width': 3213,
#    'id': 186},
#   {'file_name': 'courriergdl-1857-01-18-a-p0004.jpg',
#    'img_height': 4772,
#    'image_width': 3213,
#    'id': 187},
#   {'file_name': 'luxwort-1857-03-27-a-p0001.jpg',
#    'img_height': 4389,
#    'image_width': 2934,
#    'id': 2872},
#   {'file_name': 'luxwort-1857-02-20-a-p0003.jpg',
#    'img_height': 4367,
#    'image_width': 2898,
#    'id': 2871},
#   {'file_name': 'luxwort-1857-03-27-a-p0002.jpg',
#    'img_height': 4389,
#    'image_width': 2934,
#    'id': 2873},
#   {'file_name': 'waechtersauer-1857-12-16-a-p0002.jpg',
#    'img_height': 4594,
#    'image_width': 3035,
#    'id': 3472},
#   {'file_name': 'waechtersauer-1857-12-16-a-p0004.jpg',
#    'img_height': 4594,
#    'image_width': 3035,
#    'id': 3474},
#   {'file_name': 'waechtersauer-1857-12-16-a-p0003.jpg',
#    'img_height': 4594,
#    'image_width': 3035,
#    'id': 3473},
#   {'file_name': 'luxwort-1858-08-26-a-p0001.jpg',
#    'img_height': 4394,
#    'image_width': 2917,
#    'id': 2876},
#   {'file_name': 'courriergdl-1858-11-28-a-p0001.jpg',
#    'img_height': 4713,
#    'image_width': 3142,
#    'id': 192},
#   {'file_name': 'courriergdl-1858-11-28-a-p0002.jpg',
#    'img_height': 4713,
#    'image_width': 3142,
#    'id': 3955},
#   {'file_name': 'courriergdl-1858-05-23-a-p0004.jpg',
#    'img_height': 4748,
#    'image_width': 3224,
#    'id': 191},
#   {'file_name': 'courriergdl-1858-05-23-a-p0003.jpg',
#    'img_height': 4748,
#    'image_width': 3224,
#    'id': 190},
#   {'file_name': 'luxwort-1858-01-08-a-p0003.jpg',
#    'img_height': 4370,
#    'image_width': 2894,
#    'id': 2874},
#   {'file_name': 'luxwort-1858-08-26-a-p0002.jpg',
#    'img_height': 4394,
#    'image_width': 2917,
#    'id': 4101},
#   {'file_name': 'luxzeit1858-1858-11-11-a-p0001.jpg',
#    'img_height': 4760,
#    'image_width': 3083,
#    'id': 3169},
#   {'file_name': 'jdpl-1856-06-15-a-p0003.jpg',
#    'img_height': 7145,
#    'image_width': 5074,
#    'id': 558},
#   {'file_name': 'luxzeit1858-1858-11-11-a-p0002.jpg',
#    'img_height': 4760,
#    'image_width': 3083,
#    'id': 3170},
#   {'file_name': 'jdpl-1856-06-15-a-p0001.jpg',
#    'img_height': 7129,
#    'image_width': 5059,
#    'id': 556},
#   {'file_name': 'jdpl-1856-06-15-a-p0002.jpg',
#    'img_height': 7141,
#    'image_width': 5075,
#    'id': 557},
#   {'file_name': 'luxwort-1858-01-08-a-p0004.jpg',
#    'img_height': 4370,
#    'image_width': 2894,
#    'id': 2875},
#   {'file_name': 'luxzeit1858-1858-11-11-a-p0004.jpg',
#    'img_height': 4760,
#    'image_width': 3083,
#    'id': 3172},
#   {'file_name': 'jdpl-1856-06-15-a-p0004.jpg',
#    'img_height': 7138,
#    'image_width': 5071,
#    'id': 3688},
#   {'file_name': 'luxzeit1858-1858-11-11-a-p0003.jpg',
#    'img_height': 4760,
#    'image_width': 3083,
#    'id': 3171},
#   {'file_name': 'waechtersauer-1858-09-15-a-p0002.jpg',
#    'img_height': 4571,
#    'image_width': 3083,
#    'id': 3475},
#   {'file_name': 'jdpl-1857-07-07-a-p0001.jpg',
#    'img_height': 7378,
#    'image_width': 5339,
#    'id': 560},
#   {'file_name': 'luxwort-1859-11-27-a-p0001.jpg',
#    'img_height': 4394,
#    'image_width': 2941,
#    'id': 2877},
#   {'file_name': 'jdpl-1857-07-07-a-p0003.jpg',
#    'img_height': 7397,
#    'image_width': 5337,
#    'id': 562},
#   {'file_name': 'luxwort-1859-11-27-a-p0003.jpg',
#    'img_height': 4394,
#    'image_width': 2941,
#    'id': 2879},
#   {'file_name': 'courriergdl-1859-04-01-a-p0002.jpg',
#    'img_height': 4831,
#    'image_width': 3319,
#    'id': 193},
#   {'file_name': 'luxwort-1859-11-27-a-p0002.jpg',
#    'img_height': 4394,
#    'image_width': 2941,
#    'id': 2878},
#   {'file_name': 'jdpl-1857-07-07-a-p0004.jpg',
#    'img_height': 7393,
#    'image_width': 5355,
#    'id': 563},
#   {'file_name': 'luxwort-1859-11-27-a-p0004.jpg',
#    'img_height': 4394,
#    'image_width': 2941,
#    'id': 2880},
#   {'file_name': 'courriergdl-1859-05-08-a-p0003.jpg',
#    'img_height': 4819,
#    'image_width': 3354,
#    'id': 194},
#   {'file_name': 'waechtersauer-1859-07-30-a-p0002.jpg',
#    'img_height': 4524,
#    'image_width': 3059,
#    'id': 3477},
#   {'file_name': 'courriergdl-1859-05-08-a-p0004.jpg',
#    'img_height': 4819,
#    'image_width': 3354,
#    'id': 195},
#   {'file_name': 'waechtersauer-1859-07-30-a-p0001.jpg',
#    'img_height': 4524,
#    'image_width': 3059,
#    'id': 3476},
#   {'file_name': 'courriergdl-1860-01-25-a-p0002.jpg',
#    'img_height': 4689,
#    'image_width': 3012,
#    'id': 197},
#   {'file_name': 'courriergdl-1860-01-25-a-p0001.jpg',
#    'img_height': 4689,
#    'image_width': 3012,
#    'id': 196},
#   {'file_name': 'jdpl-1857-07-07-a-p0002.jpg',
#    'img_height': 7395,
#    'image_width': 5359,
#    'id': 561},
#   {'file_name': 'courriergdl-1860-01-25-a-p0003.jpg',
#    'img_height': 4689,
#    'image_width': 3012,
#    'id': 198},
#   {'file_name': 'courriergdl-1860-01-25-a-p0004.jpg',
#    'img_height': 4689,
#    'image_width': 3012,
#    'id': 3617},
#   {'file_name': 'waechtersauer-1860-01-04-a-p0001.jpg',
#    'img_height': 4594,
#    'image_width': 3047,
#    'id': 3478},
#   {'file_name': 'waechtersauer-1860-01-04-a-p0002.jpg',
#    'img_height': 4594,
#    'image_width': 3047,
#    'id': 3479},
#   {'file_name': 'lunion-1860-12-11-a-p0004.jpg',
#    'img_height': 5799,
#    'image_width': 3744,
#    'id': 3699},
#   {'file_name': 'courriergdl-1861-01-06-a-p0001.jpg',
#    'img_height': 5728,
#    'image_width': 3720,
#    'id': 199},
#   {'file_name': 'lunion-1860-12-11-a-p0001.jpg',
#    'img_height': 5799,
#    'image_width': 3744,
#    'id': 1148},
#   {'file_name': 'lunion-1860-12-11-a-p0002.jpg',
#    'img_height': 5799,
#    'image_width': 3744,
#    'id': 1149},
#   {'file_name': 'lunion-1860-12-11-a-p0003.jpg',
#    'img_height': 5799,
#    'image_width': 3744,
#    'id': 1150},
#   {'file_name': 'lunion-1861-08-13-a-p0001.jpg',
#    'img_height': 5587,
#    'image_width': 3638,
#    'id': 1151},
#   {'file_name': 'lunion-1861-08-13-a-p0003.jpg',
#    'img_height': 5587,
#    'image_width': 3638,
#    'id': 1153},
#   {'file_name': 'courriergdl-1861-01-06-a-p0002.jpg',
#    'img_height': 5728,
#    'image_width': 3720,
#    'id': 200},
#   {'file_name': 'courriergdl-1861-01-06-a-p0004.jpg',
#    'img_height': 5728,
#    'image_width': 3720,
#    'id': 202},
#   {'file_name': 'lunion-1861-08-13-a-p0002.jpg',
#    'img_height': 5587,
#    'image_width': 3638,
#    'id': 1152},
#   {'file_name': 'courriergdl-1861-01-06-a-p0003.jpg',
#    'img_height': 5728,
#    'image_width': 3720,
#    'id': 201},
#   {'file_name': 'lunion-1861-08-13-a-p0004.jpg',
#    'img_height': 5587,
#    'image_width': 3638,
#    'id': 1154},
#   {'file_name': 'luxwort-1861-03-01-a-p0002.jpg',
#    'img_height': 5457,
#    'image_width': 3461,
#    'id': 2882},
#   {'file_name': 'waechtersauer-1861-06-12-a-p0001.jpg',
#    'img_height': 4488,
#    'image_width': 3106,
#    'id': 3481},
#   {'file_name': 'waechtersauer-1861-03-30-a-p0004.jpg',
#    'img_height': 4524,
#    'image_width': 3094,
#    'id': 3942},
#   {'file_name': 'waechtersauer-1861-06-12-a-p0002.jpg',
#    'img_height': 4488,
#    'image_width': 3106,
#    'id': 3482},
#   {'file_name': 'waechtersauer-1861-03-30-a-p0003.jpg',
#    'img_height': 4524,
#    'image_width': 3094,
#    'id': 3480},
#   {'file_name': 'luxwort-1861-03-01-a-p0003.jpg',
#    'img_height': 5457,
#    'image_width': 3461,
#    'id': 2883},
#   {'file_name': 'luxwort-1861-03-01-a-p0001.jpg',
#    'img_height': 5457,
#    'image_width': 3461,
#    'id': 2881},
#   {'file_name': 'luxwort-1861-03-01-a-p0004.jpg',
#    'img_height': 5457,
#    'image_width': 3461,
#    'id': 2884},
#   {'file_name': 'courriergdl-1862-07-15-a-p0001.jpg',
#    'img_height': 5492,
#    'image_width': 3697,
#    'id': 203},
#   {'file_name': 'courriergdl-1862-07-15-a-p0004.jpg',
#    'img_height': 5492,
#    'image_width': 3697,
#    'id': 205},
#   {'file_name': 'courriergdl-1862-07-15-a-p0002.jpg',
#    'img_height': 5492,
#    'image_width': 3697,
#    'id': 3956},
#   {'file_name': 'courriergdl-1862-07-15-a-p0003.jpg',
#    'img_height': 5492,
#    'image_width': 3697,
#    'id': 204},
#   {'file_name': 'lunion-1862-01-19-a-p0001.jpg',
#    'img_height': 5811,
#    'image_width': 3697,
#    'id': 1155},
#   {'file_name': 'lunion-1862-01-19-a-p0002.jpg',
#    'img_height': 5811,
#    'image_width': 3697,
#    'id': 3974},
#   {'file_name': 'lunion-1862-01-19-a-p0003.jpg',
#    'img_height': 5811,
#    'image_width': 3697,
#    'id': 3975},
#   {'file_name': 'waechtersauer-1862-05-03-a-p0002.jpg',
#    'img_height': 4606,
#    'image_width': 3118,
#    'id': 3483},
#   {'file_name': 'waechtersauer-1862-07-16-a-p0003.jpg',
#    'img_height': 4795,
#    'image_width': 3059,
#    'id': 3484},
#   {'file_name': 'luxwort-1862-08-03-a-p0001.jpg',
#    'img_height': 5472,
#    'image_width': 3503,
#    'id': 2887},
#   {'file_name': 'lunion-1862-01-19-a-p0004.jpg',
#    'img_height': 5811,
#    'image_width': 3697,
#    'id': 1156},
#   {'file_name': 'luxwort-1862-06-13-a-p0004.jpg',
#    'img_height': 5469,
#    'image_width': 3503,
#    'id': 2886},
#   {'file_name': 'luxwort-1862-08-03-a-p0002.jpg',
#    'img_height': 5472,
#    'image_width': 3503,
#    'id': 2888},
#   {'file_name': 'luxwort-1862-06-13-a-p0003.jpg',
#    'img_height': 5469,
#    'image_width': 3503,
#    'id': 2885},
#   {'file_name': 'waechtersauer-1862-07-16-a-p0004.jpg',
#    'img_height': 4795,
#    'image_width': 3059,
#    'id': 3485},
#   {'file_name': 'luxwort-1863-01-13-a-p0002.jpg',
#    'img_height': 5471,
#    'image_width': 3501,
#    'id': 2890},
#   {'file_name': 'lunion-1863-03-11-a-p0003.jpg',
#    'img_height': 5669,
#    'image_width': 3661,
#    'id': 1158},
#   {'file_name': 'lunion-1863-03-11-a-p0004.jpg',
#    'img_height': 5669,
#    'image_width': 3661,
#    'id': 1159},
#   {'file_name': 'lunion-1863-03-11-a-p0001.jpg',
#    'img_height': 5669,
#    'image_width': 3661,
#    'id': 1157},
#   {'file_name': 'courriergdl-1863-12-31-a-p0004.jpg',
#    'img_height': 5835,
#    'image_width': 3732,
#    'id': 209},
#   {'file_name': 'luxwort-1863-01-13-a-p0001.jpg',
#    'img_height': 5471,
#    'image_width': 3501,
#    'id': 2889},
#   {'file_name': 'courriergdl-1863-12-31-a-p0001.jpg',
#    'img_height': 5835,
#    'image_width': 3732,
#    'id': 206},
#   {'file_name': 'courriergdl-1863-12-31-a-p0002.jpg',
#    'img_height': 5835,
#    'image_width': 3732,
#    'id': 207},
#   {'file_name': 'luxwort-1863-05-23-a-p0003.jpg',
#    'img_height': 5524,
#    'image_width': 3520,
#    'id': 2891},
#   {'file_name': 'courriergdl-1863-12-31-a-p0003.jpg',
#    'img_height': 5835,
#    'image_width': 3732,
#    'id': 208},
#   {'file_name': 'waechtersauer-1863-03-03-a-p0002.jpg',
#    'img_height': 4748,
#    'image_width': 3130,
#    'id': 3486},
#   {'file_name': 'waechtersauer-1863-12-24-a-p0003.jpg',
#    'img_height': 4748,
#    'image_width': 3142,
#    'id': 3487},
#   {'file_name': 'waechtersauer-1863-12-24-a-p0004.jpg',
#    'img_height': 4748,
#    'image_width': 3142,
#    'id': 3488},
#   {'file_name': 'luxwort-1863-05-23-a-p0004.jpg',
#    'img_height': 5524,
#    'image_width': 3520,
#    'id': 2892},
#   {'file_name': 'courriergdl-1864-06-09-a-p0001.jpg',
#    'img_height': 5646,
#    'image_width': 3756,
#    'id': 210},
#   {'file_name': 'jdpl-1862-07-27-a-p0001.jpg',
#    'img_height': 7435,
#    'image_width': 5301,
#    'id': 565},
#   {'file_name': 'jdpl-1862-07-27-a-p0003.jpg',
#    'img_height': 7444,
#    'image_width': 5311,
#    'id': 567},
#   {'file_name': 'jdpl-1862-07-27-a-p0004.jpg',
#    'img_height': 7374,
#    'image_width': 5282,
#    'id': 3689},
#   {'file_name': 'jdpl-1862-07-27-a-p0002.jpg',
#    'img_height': 7433,
#    'image_width': 5341,
#    'id': 566},
#   {'file_name': 'courriergdl-1864-06-09-a-p0004.jpg',
#    'img_height': 5646,
#    'image_width': 3756,
#    'id': 212},
#   {'file_name': 'lunion-1864-11-18-a-p0003.jpg',
#    'img_height': 5705,
#    'image_width': 3709,
#    'id': 1161},
#   {'file_name': 'courriergdl-1864-06-09-a-p0003.jpg',
#    'img_height': 5646,
#    'image_width': 3756,
#    'id': 211},
#   {'file_name': 'lunion-1864-11-18-a-p0004.jpg',
#    'img_height': 5705,
#    'image_width': 3709,
#    'id': 1162},
#   {'file_name': 'luxwort-1864-01-15-a-p0001.jpg',
#    'img_height': 5480,
#    'image_width': 3484,
#    'id': 2894},
#   {'file_name': 'luxwort-1864-01-15-a-p0002.jpg',
#    'img_height': 5480,
#    'image_width': 3484,
#    'id': 2895},
#   {'file_name': 'waechtersauer-1864-12-25-a-p0003.jpg',
#    'img_height': 4831,
#    'image_width': 3142,
#    'id': 3489},
#   {'file_name': 'lunion-1864-11-18-a-p0002.jpg',
#    'img_height': 5705,
#    'image_width': 3709,
#    'id': 1160},
#   {'file_name': 'waechtersauer-1864-12-25-a-p0004.jpg',
#    'img_height': 4831,
#    'image_width': 3142,
#    'id': 3943},
#   {'file_name': 'luxwort-1864-01-15-a-p0003.jpg',
#    'img_height': 5480,
#    'image_width': 3484,
#    'id': 2896},
#   {'file_name': 'jdpl-1863-09-04-a-p0001.jpg',
#    'img_height': 7395,
#    'image_width': 5380,
#    'id': 569},
#   {'file_name': 'jdpl-1863-09-04-a-p0002.jpg',
#    'img_height': 7362,
#    'image_width': 5362,
#    'id': 570},
#   {'file_name': 'jdpl-1863-07-26-a-p0003.jpg',
#    'img_height': 7375,
#    'image_width': 5332,
#    'id': 568},
#   {'file_name': 'jdpl-1863-07-26-a-p0004.jpg',
#    'img_height': 7414,
#    'image_width': 5357,
#    'id': 3557},
#   {'file_name': 'courriergdl-1865-01-24-a-p0002.jpg',
#    'img_height': 5587,
#    'image_width': 3803,
#    'id': 215},
#   {'file_name': 'lunion-1865-03-05-a-p0001.jpg',
#    'img_height': 5622,
#    'image_width': 3780,
#    'id': 1163},
#   {'file_name': 'courriergdl-1865-01-18-a-p0003.jpg',
#    'img_height': 5587,
#    'image_width': 3803,
#    'id': 213},
#   {'file_name': 'luxwort-1865-12-18-a-p0004.jpg',
#    'img_height': 5268,
#    'image_width': 3543,
#    'id': 2900},
#   {'file_name': 'courriergdl-1865-01-18-a-p0004.jpg',
#    'img_height': 5587,
#    'image_width': 3803,
#    'id': 214},
#   {'file_name': 'lunion-1865-03-05-a-p0002.jpg',
#    'img_height': 5622,
#    'image_width': 3780,
#    'id': 1164},
#   {'file_name': 'lunion-1865-03-05-a-p0004.jpg',
#    'img_height': 5622,
#    'image_width': 3780,
#    'id': 1165},
#   {'file_name': 'lunion-1865-03-05-a-p0003.jpg',
#    'img_height': 5622,
#    'image_width': 3780,
#    'id': 3700},
#   {'file_name': 'luxwort-1865-12-18-a-p0001.jpg',
#    'img_height': 5268,
#    'image_width': 3543,
#    'id': 2897},
#   {'file_name': 'luxwort-1865-12-18-a-p0002.jpg',
#    'img_height': 5268,
#    'image_width': 3543,
#    'id': 2898},
#   {'file_name': 'waechtersauer-1865-02-19-a-p0003.jpg',
#    'img_height': 4748,
#    'image_width': 3177,
#    'id': 3491},
#   {'file_name': 'waechtersauer-1865-02-19-a-p0002.jpg',
#    'img_height': 4748,
#    'image_width': 3177,
#    'id': 3490},
#   {'file_name': 'luxwort-1865-12-18-a-p0003.jpg',
#    'img_height': 5268,
#    'image_width': 3543,
#    'id': 2899},
#   {'file_name': 'waechtersauer-1865-02-19-a-p0004.jpg',
#    'img_height': 4748,
#    'image_width': 3177,
#    'id': 3944},
#   {'file_name': 'jdpl-1864-04-26-a-p0001.jpg',
#    'img_height': 7387,
#    'image_width': 5333,
#    'id': 572},
#   {'file_name': 'jdpl-1864-04-26-a-p0002.jpg',
#    'img_height': 7383,
#    'image_width': 5332,
#    'id': 573},
#   {'file_name': 'courriergdl-1866-11-01-a-p0001.jpg',
#    'img_height': 5657,
#    'image_width': 3756,
#    'id': 216},
#   {'file_name': 'courriergdl-1866-11-01-a-p0004.jpg',
#    'img_height': 5657,
#    'image_width': 3756,
#    'id': 219},
#   {'file_name': 'jdpl-1864-03-03-a-p0004.jpg',
#    'img_height': 7419,
#    'image_width': 5358,
#    'id': 3690},
#   {'file_name': 'courriergdl-1866-11-01-a-p0002.jpg',
#    'img_height': 5657,
#    'image_width': 3756,
#    'id': 217},
#   {'file_name': 'jdpl-1864-02-29-a-p0003.jpg',
#    'img_height': 7392,
#    'image_width': 5349,
#    'id': 571},
#   {'file_name': 'luxwort-1866-09-02-a-p0001.jpg',
#    'img_height': 5291,
#    'image_width': 3591,
#    'id': 2901},
#   {'file_name': 'courriergdl-1866-11-01-a-p0003.jpg',
#    'img_height': 5657,
#    'image_width': 3756,
#    'id': 218},
#   {'file_name': 'lunion-1866-05-01-a-p0004.jpg',
#    'img_height': 5622,
#    'image_width': 3673,
#    'id': 1168},
#   {'file_name': 'luxwort-1866-09-02-a-p0002.jpg',
#    'img_height': 5291,
#    'image_width': 3591,
#    'id': 2902},
#   {'file_name': 'lunion-1866-05-01-a-p0003.jpg',
#    'img_height': 5622,
#    'image_width': 3673,
#    'id': 1167},
#   {'file_name': 'lunion-1866-05-01-a-p0001.jpg',
#    'img_height': 5622,
#    'image_width': 3673,
#    'id': 1166},
#   {'file_name': 'lunion-1866-05-01-a-p0002.jpg',
#    'img_height': 5622,
#    'image_width': 3673,
#    'id': 3977},
#   {'file_name': 'luxwort-1866-09-19-a-p0004.jpg',
#    'img_height': 5280,
#    'image_width': 3542,
#    'id': 2904},
#   {'file_name': 'luxwort-1866-09-19-a-p0003.jpg',
#    'img_height': 5280,
#    'image_width': 3542,
#    'id': 2903},
#   {'file_name': 'waechtersauer-1866-06-24-a-p0002.jpg',
#    'img_height': 4831,
#    'image_width': 3213,
#    'id': 3494},
#   {'file_name': 'waechtersauer-1866-06-10-a-p0003.jpg',
#    'img_height': 4831,
#    'image_width': 3213,
#    'id': 3492},
#   {'file_name': 'waechtersauer-1866-06-10-a-p0004.jpg',
#    'img_height': 4831,
#    'image_width': 3213,
#    'id': 3493},
#   {'file_name': 'courriergdl-1867-05-29-a-p0002.jpg',
#    'img_height': 5717,
#    'image_width': 3720,
#    'id': 222},
#   {'file_name': 'lunion-1867-03-14-a-p0003.jpg',
#    'img_height': 5669,
#    'image_width': 3732,
#    'id': 1171},
#   {'file_name': 'lunion-1867-03-03-a-p0002.jpg',
#    'img_height': 5657,
#    'image_width': 3732,
#    'id': 1170},
#   {'file_name': 'courriergdl-1867-05-29-a-p0003.jpg',
#    'img_height': 5717,
#    'image_width': 3720,
#    'id': 223},
#   {'file_name': 'lunion-1867-03-03-a-p0001.jpg',
#    'img_height': 5657,
#    'image_width': 3732,
#    'id': 1169},
#   {'file_name': 'courriergdl-1867-05-29-a-p0001.jpg',
#    'img_height': 5717,
#    'image_width': 3720,
#    'id': 221},
#   {'file_name': 'luxwort-1867-08-23-a-p0002.jpg',
#    'img_height': 5256,
#    'image_width': 3531,
#    'id': 2907},
#   {'file_name': 'luxwort-1867-08-23-a-p0001.jpg',
#    'img_height': 5256,
#    'image_width': 3531,
#    'id': 2906},
#   {'file_name': 'waechtersauer-1867-07-18-a-p0002.jpg',
#    'img_height': 4843,
#    'image_width': 3177,
#    'id': 3496},
#   {'file_name': 'courriergdl-1867-05-29-a-p0004.jpg',
#    'img_height': 5717,
#    'image_width': 3720,
#    'id': 224},
#   {'file_name': 'lunion-1867-03-14-a-p0004.jpg',
#    'img_height': 5669,
#    'image_width': 3732,
#    'id': 1172},
#   {'file_name': 'luxwort-1867-07-16-a-p0003.jpg',
#    'img_height': 5239,
#    'image_width': 3490,
#    'id': 2905},
#   {'file_name': 'waechtersauer-1867-07-18-a-p0001.jpg',
#    'img_height': 4843,
#    'image_width': 3177,
#    'id': 3495},
#   {'file_name': 'waechtersauer-1867-07-18-a-p0003.jpg',
#    'img_height': 4843,
#    'image_width': 3177,
#    'id': 3497},
#   {'file_name': 'luxwort-1868-03-28-a-p0001.jpg',
#    'img_height': 5191,
#    'image_width': 3516,
#    'id': 2908},
#   {'file_name': 'courriergdl-1868-02-27-a-p0004.jpg',
#    'img_height': 5764,
#    'image_width': 3756,
#    'id': 228},
#   {'file_name': 'lunion-1868-08-15-a-p0002.jpg',
#    'img_height': 5587,
#    'image_width': 3602,
#    'id': 1176},
#   {'file_name': 'courriergdl-1868-02-27-a-p0002.jpg',
#    'img_height': 5764,
#    'image_width': 3756,
#    'id': 226},
#   {'file_name': 'lunion-1868-08-06-a-p0003.jpg',
#    'img_height': 5587,
#    'image_width': 3602,
#    'id': 1173},
#   {'file_name': 'courriergdl-1868-02-27-a-p0001.jpg',
#    'img_height': 5764,
#    'image_width': 3756,
#    'id': 225},
#   {'file_name': 'luxwort-1868-03-28-a-p0002.jpg',
#    'img_height': 5191,
#    'image_width': 3516,
#    'id': 2909},
#   {'file_name': 'lunion-1868-08-06-a-p0004.jpg',
#    'img_height': 5587,
#    'image_width': 3602,
#    'id': 1174},
#   {'file_name': 'lunion-1868-08-15-a-p0001.jpg',
#    'img_height': 5587,
#    'image_width': 3602,
#    'id': 1175},
#   {'file_name': 'avenirgdl-1868-09-26-a-p0002.jpg',
#    'img_height': 6331,
#    'image_width': 4406,
#    'id': 96},
#   {'file_name': 'courriergdl-1868-02-27-a-p0003.jpg',
#    'img_height': 5764,
#    'image_width': 3756,
#    'id': 227},
#   {'file_name': 'avenirgdl-1868-09-26-a-p0003.jpg',
#    'img_height': 6331,
#    'image_width': 4406,
#    'id': 97},
#   {'file_name': 'avenirgdl-1868-09-26-a-p0001.jpg',
#    'img_height': 6331,
#    'image_width': 4406,
#    'id': 95},
#   {'file_name': 'avenirgdl-1868-09-26-a-p0004.jpg',
#    'img_height': 6331,
#    'image_width': 4406,
#    'id': 98},
#   {'file_name': 'luxwort-1868-11-01-a-p0003.jpg',
#    'img_height': 5197,
#    'image_width': 3508,
#    'id': 2910},
#   {'file_name': 'lunion-1869-09-22-a-p0002.jpg',
#    'img_height': 5740,
#    'image_width': 3685,
#    'id': 1179},
#   {'file_name': 'lunion-1869-07-26-a-p0004.jpg',
#    'img_height': 5728,
#    'image_width': 3697,
#    'id': 3701},
#   {'file_name': 'lunion-1869-09-22-a-p0001.jpg',
#    'img_height': 5740,
#    'image_width': 3685,
#    'id': 1178},
#   {'file_name': 'luxwort-1869-08-08-a-p0002.jpg',
#    'img_height': 4944,
#    'image_width': 3263,
#    'id': 2912},
#   {'file_name': 'luxwort-1869-08-08-a-p0001.jpg',
#    'img_height': 4944,
#    'image_width': 3263,
#    'id': 2911},
#   {'file_name': 'lunion-1869-07-26-a-p0003.jpg',
#    'img_height': 5728,
#    'image_width': 3697,
#    'id': 1177},
#   {'file_name': 'avenirgdl-1869-12-24-a-p0004.jpg',
#    'img_height': 6307,
#    'image_width': 4394,
#    'id': 102},
#   {'file_name': 'avenirgdl-1869-09-14-a-p0003.jpg',
#    'img_height': 6272,
#    'image_width': 4370,
#    'id': 99},
#   {'file_name': 'avenirgdl-1869-12-21-a-p0001.jpg',
#    'img_height': 6307,
#    'image_width': 4394,
#    'id': 100},
#   {'file_name': 'avenirgdl-1869-12-21-a-p0002.jpg',
#    'img_height': 6307,
#    'image_width': 4394,
#    'id': 101},
#   {'file_name': 'luxwort-1869-08-08-a-p0004.jpg',
#    'img_height': 4944,
#    'image_width': 3263,
#    'id': 2914},
#   {'file_name': 'volkfreu1869-1869-09-14-a-p0002.jpg',
#    'img_height': 4843,
#    'image_width': 3142,
#    'id': 3431},
#   {'file_name': 'volkfreu1869-1869-09-14-a-p0001.jpg',
#    'img_height': 4843,
#    'image_width': 3142,
#    'id': 3430},
#   {'file_name': 'volkfreu1869-1869-06-29-a-p0003.jpg',
#    'img_height': 4831,
#    'image_width': 3177,
#    'id': 3428},
#   {'file_name': 'volkfreu1869-1869-06-29-a-p0004.jpg',
#    'img_height': 4831,
#    'image_width': 3177,
#    'id': 3429},
#   {'file_name': 'luxwort-1869-08-08-a-p0003.jpg',
#    'img_height': 4944,
#    'image_width': 3263,
#    'id': 2913},
#   {'file_name': 'waechtersauer-1869-01-07-a-p0001.jpg',
#    'img_height': 4878,
#    'image_width': 3272,
#    'id': 3498},
#   {'file_name': 'legaulois-1868-09-02-a-p0002.jpg',
#    'img_height': 7372,
#    'image_width': 5333,
#    'id': 754},
#   {'file_name': 'legaulois-1868-09-02-a-p0004.jpg',
#    'img_height': 7364,
#    'image_width': 5347,
#    'id': 756},
#   {'file_name': 'legaulois-1868-09-02-a-p0003.jpg',
#    'img_height': 7362,
#    'image_width': 5374,
#    'id': 755},
#   {'file_name': 'waechtersauer-1869-01-07-a-p0002.jpg',
#    'img_height': 4878,
#    'image_width': 3272,
#    'id': 3499},
#   {'file_name': 'waechtersauer-1869-01-07-a-p0003.jpg',
#    'img_height': 4878,
#    'image_width': 3272,
#    'id': 3500},
#   {'file_name': 'waechtersauer-1869-01-07-a-p0004.jpg',
#    'img_height': 4878,
#    'image_width': 3272,
#    'id': 3501},
#   {'file_name': 'lunion-1870-10-15-a-p0001.jpg',
#    'img_height': 5516,
#    'image_width': 3567,
#    'id': 1181},
#   {'file_name': 'avenirgdl-1870-03-26-a-p0001.jpg',
#    'img_height': 6331,
#    'image_width': 4346,
#    'id': 105},
#   {'file_name': 'lunion-1870-10-04-a-p0004.jpg',
#    'img_height': 5539,
#    'image_width': 3567,
#    'id': 3702},
#   {'file_name': 'avenirgdl-1870-03-26-a-p0002.jpg',
#    'img_height': 6331,
#    'image_width': 4346,
#    'id': 106},
#   {'file_name': 'volkfreu1869-1870-08-04-a-p0001.jpg',
#    'img_height': 4701,
#    'image_width': 3083,
#    'id': 3433},
#   {'file_name': 'luxwort-1870-05-30-a-p0001.jpg',
#    'img_height': 5445,
#    'image_width': 3673,
#    'id': 2917},
#   {'file_name': 'luxwort-1870-05-30-a-p0002.jpg',
#    'img_height': 5174,
#    'image_width': 3465,
#    'id': 2918},
#   {'file_name': 'lunion-1870-10-04-a-p0003.jpg',
#    'img_height': 5539,
#    'image_width': 3567,
#    'id': 1180},
#   {'file_name': 'avenirgdl-1870-02-11-a-p0003.jpg',
#    'img_height': 6319,
#    'image_width': 4394,
#    'id': 103},
#   {'file_name': 'avenirgdl-1870-02-11-a-p0004.jpg',
#    'img_height': 6319,
#    'image_width': 4394,
#    'id': 104},
#   {'file_name': 'volkfreu1869-1870-08-04-a-p0002.jpg',
#    'img_height': 4701,
#    'image_width': 3083,
#    'id': 3434},
#   {'file_name': 'luxwort-1870-04-07-a-p0003.jpg',
#    'img_height': 6295,
#    'image_width': 4252,
#    'id': 2915},
#   {'file_name': 'luxwort-1870-04-07-a-p0004.jpg',
#    'img_height': 6295,
#    'image_width': 4252,
#    'id': 2916},
#   {'file_name': 'volkfreu1869-1870-01-16-a-p0003.jpg',
#    'img_height': 4748,
#    'image_width': 3106,
#    'id': 3432},
#   {'file_name': 'legaulois-1869-12-28-a-p0002.jpg',
#    'img_height': 7354,
#    'image_width': 5262,
#    'id': 757},
#   {'file_name': 'indeplux-1871-10-04-a-p0001.jpg',
#    'img_height': 5759,
#    'image_width': 3800,
#    'id': 333},
#   {'file_name': 'lunion-1871-05-16-a-p0001.jpg',
#    'img_height': 5622,
#    'image_width': 3626,
#    'id': 1182},
#   {'file_name': 'indeplux-1871-10-04-a-p0004.jpg',
#    'img_height': 5759,
#    'image_width': 3800,
#    'id': 336},
#   {'file_name': 'indeplux-1871-10-04-a-p0003.jpg',
#    'img_height': 5759,
#    'image_width': 3800,
#    'id': 335},
#   {'file_name': 'avenirgdl-1871-05-29-a-p0001.jpg',
#    'img_height': 6909,
#    'image_width': 5102,
#    'id': 107},
#   {'file_name': 'indeplux-1871-10-04-a-p0002.jpg',
#    'img_height': 5759,
#    'image_width': 3800,
#    'id': 334},
#   {'file_name': 'lunion-1871-05-16-a-p0002.jpg',
#    'img_height': 5622,
#    'image_width': 3626,
#    'id': 3978},
#   {'file_name': 'lunion-1871-05-16-a-p0003.jpg',
#    'img_height': 5622,
#    'image_width': 3626,
#    'id': 1183},
#   {'file_name': 'avenirgdl-1871-05-29-a-p0002.jpg',
#    'img_height': 6909,
#    'image_width': 5102,
#    'id': 108},
#   {'file_name': 'avenirgdl-1871-08-31-a-p0003.jpg',
#    'img_height': 7075,
#    'image_width': 4984,
#    'id': 109},
#   {'file_name': 'avenirgdl-1871-08-31-a-p0004.jpg',
#    'img_height': 7075,
#    'image_width': 4984,
#    'id': 110},
#   {'file_name': 'lunion-1871-05-16-a-p0004.jpg',
#    'img_height': 5622,
#    'image_width': 3626,
#    'id': 3703},
#   {'file_name': 'legaulois-1870-06-03-a-p0004.jpg',
#    'img_height': 7372,
#    'image_width': 5314,
#    'id': 3691},
#   {'file_name': 'volkfreu1869-1871-06-15-a-p0001.jpg',
#    'img_height': 4760,
#    'image_width': 3165,
#    'id': 3435},
#   {'file_name': 'legaulois-1870-09-14-a-p0002.jpg',
#    'img_height': 7340,
#    'image_width': 5267,
#    'id': 758},
#   {'file_name': 'volkfreu1869-1871-06-15-a-p0002.jpg',
#    'img_height': 4760,
#    'image_width': 3165,
#    'id': 3436},
#   {'file_name': 'volkfreu1869-1871-12-03-a-p0003.jpg',
#    'img_height': 4760,
#    'image_width': 3083,
#    'id': 3437},
#   {'file_name': 'volkfreu1869-1871-12-03-a-p0004.jpg',
#    'img_height': 4760,
#    'image_width': 3083,
#    'id': 3438},
#   {'file_name': 'luxwort-1871-12-20-a-p0001.jpg',
#    'img_height': 6052,
#    'image_width': 4081,
#    'id': 2920},
#   {'file_name': 'luxwort-1871-12-20-a-p0002.jpg',
#    'img_height': 6236,
#    'image_width': 4264,
#    'id': 2921},
#   {'file_name': 'luxwort-1871-06-15-a-p0004.jpg',
#    'img_height': 6154,
#    'image_width': 4146,
#    'id': 2919},
#   {'file_name': 'indeplux-1872-03-28-a-p0002.jpg',
#    'img_height': 5749,
#    'image_width': 3946,
#    'id': 337},
#   {'file_name': 'indeplux-1872-03-28-a-p0004.jpg',
#    'img_height': 5749,
#    'image_width': 3946,
#    'id': 3633},
#   {'file_name': 'indeplux-1872-03-28-a-p0003.jpg',
#    'img_height': 5749,
#    'image_width': 3946,
#    'id': 338},
#   {'file_name': 'volkfreu1869-1872-10-23-a-p0001.jpg',
#    'img_height': 5504,
#    'image_width': 3602,
#    'id': 3441},
#   {'file_name': 'volkfreu1869-1872-10-23-a-p0002.jpg',
#    'img_height': 5504,
#    'image_width': 3602,
#    'id': 3442},
#   {'file_name': 'volkfreu1869-1872-10-01-a-p0003.jpg',
#    'img_height': 5539,
#    'image_width': 3638,
#    'id': 3439},
#   {'file_name': 'luxwort-1872-01-25-a-p0002.jpg',
#    'img_height': 6272,
#    'image_width': 4276,
#    'id': 2925},
#   {'file_name': 'volkfreu1869-1872-10-01-a-p0004.jpg',
#    'img_height': 5539,
#    'image_width': 3638,
#    'id': 3440},
#   {'file_name': 'luxwort-1872-01-20-a-p0004.jpg',
#    'img_height': 6156,
#    'image_width': 4193,
#    'id': 2923},
#   {'file_name': 'luxwort-1872-01-25-a-p0001.jpg',
#    'img_height': 6272,
#    'image_width': 4276,
#    'id': 2924},
#   {'file_name': 'luxwort-1872-01-20-a-p0003.jpg',
#    'img_height': 6295,
#    'image_width': 4276,
#    'id': 2922},
#   {'file_name': 'legaulois-1871-10-29-a-p0002.jpg',
#    'img_height': 7352,
#    'image_width': 5307,
#    'id': 761},
#   {'file_name': 'legaulois-1871-10-29-a-p0001.jpg',
#    'img_height': 7391,
#    'image_width': 5329,
#    'id': 760},
#   {'file_name': 'indeplux-1873-12-09-a-p0004.jpg',
#    'img_height': 5814,
#    'image_width': 3901,
#    'id': 3635},
#   {'file_name': 'indeplux-1873-12-09-a-p0001.jpg',
#    'img_height': 5814,
#    'image_width': 3901,
#    'id': 340},
#   {'file_name': 'indeplux-1873-12-09-a-p0002.jpg',
#    'img_height': 5814,
#    'image_width': 3901,
#    'id': 341},
#   {'file_name': 'indeplux-1873-12-09-a-p0003.jpg',
#    'img_height': 5814,
#    'image_width': 3901,
#    'id': 3634},
#   {'file_name': 'luxwort-1873-04-23-a-p0001.jpg',
#    'img_height': 6165,
#    'image_width': 4217,
#    'id': 2926},
#   {'file_name': 'volkfreu1869-1873-12-17-a-p0001.jpg',
#    'img_height': 5539,
#    'image_width': 3661,
#    'id': 3444},
#   {'file_name': 'luxwort-1873-04-23-a-p0002.jpg',
#    'img_height': 6165,
#    'image_width': 4217,
#    'id': 2927},
#   {'file_name': 'luxwort-1873-05-06-a-p0003.jpg',
#    'img_height': 6053,
#    'image_width': 4086,
#    'id': 2928},
#   {'file_name': 'luxwort-1873-05-06-a-p0004.jpg',
#    'img_height': 6283,
#    'image_width': 4205,
#    'id': 2929},
#   {'file_name': 'volkfreu1869-1873-12-17-a-p0002.jpg',
#    'img_height': 5539,
#    'image_width': 3661,
#    'id': 3445},
#   {'file_name': 'legaulois-1872-01-12-a-p0002.jpg',
#    'img_height': 7359,
#    'image_width': 5378,
#    'id': 762},
#   {'file_name': 'volkfreu1869-1873-04-18-a-p0003.jpg',
#    'img_height': 5504,
#    'image_width': 3650,
#    'id': 3443},
#   {'file_name': 'legaulois-1872-01-12-a-p0003.jpg',
#    'img_height': 7361,
#    'image_width': 5323,
#    'id': 763},
#   {'file_name': 'legaulois-1872-01-12-a-p0004.jpg',
#    'img_height': 7345,
#    'image_width': 5337,
#    'id': 764},
#   {'file_name': 'indeplux-1874-04-12-a-p0002.jpg',
#    'img_height': 5704,
#    'image_width': 3896,
#    'id': 344},
#   {'file_name': 'indeplux-1874-04-09-a-p0004.jpg',
#    'img_height': 5724,
#    'image_width': 3826,
#    'id': 343},
#   {'file_name': 'indeplux-1874-04-09-a-p0003.jpg',
#    'img_height': 5724,
#    'image_width': 3826,
#    'id': 342},
#   {'file_name': 'volkfreu1869-1874-02-08-a-p0001.jpg',
#    'img_height': 5539,
#    'image_width': 3638,
#    'id': 3446},
#   {'file_name': 'volkfreu1869-1874-02-08-a-p0002.jpg',
#    'img_height': 5539,
#    'image_width': 3638,
#    'id': 3447},
#   {'file_name': 'waeschfra-1874-11-29-a-p0001.jpg',
#    'img_height': 3997,
# ...
#    'area': 13708,
#    'iscrowd': 0,
#    'id': 921,
#    'segmentation': [[2235, 1816, 2533, 1816, 2533, 1862, 2235, 1862]]},
#   {'bbox': [2293, 2149, 187, 43],
#    'image_id': 247,
#    'category_id': 0,
#    'area': 8041,
#    'iscrowd': 0,
#    'id': 922,
#    'segmentation': [[2293, 2149, 2480, 2149, 2480, 2192, 2293, 2192]]},
#   {'bbox': [2267, 2437, 253, 43],
#    'image_id': 247,
#    'category_id': 0,
#    'area': 10879,
#    'iscrowd': 0,
#    'id': 923,
#    'segmentation': [[2267, 2437, 2520, 2437, 2520, 2480, 2267, 2480]]},
#   {'bbox': [2044, 2703, 361, 44],
#    'image_id': 247,
#    'category_id': 0,
#    'area': 15884,
#    'iscrowd': 0,
#    'id': 924,
#    'segmentation': [[2044, 2703, 2405, 2703, 2405, 2747, 2044, 2747]]},
#   {'bbox': [325, 196, 429, 50],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 21450,
#    'iscrowd': 0,
#    'id': 925,
#    'segmentation': [[325, 196, 754, 196, 754, 246, 325, 246]]},
#   {'bbox': [414, 2613, 264, 44],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 11616,
#    'iscrowd': 0,
#    'id': 926,
#    'segmentation': [[414, 2613, 678, 2613, 678, 2657, 414, 2657]]},
#   {'bbox': [421, 2855, 248, 46],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 11408,
#    'iscrowd': 0,
#    'id': 927,
#    'segmentation': [[421, 2855, 669, 2855, 669, 2901, 421, 2901]]},
#   {'bbox': [447, 3098, 190, 41],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 7790,
#    'iscrowd': 0,
#    'id': 928,
#    'segmentation': [[447, 3098, 637, 3098, 637, 3139, 447, 3139]]},
#   {'bbox': [330, 3432, 427, 40],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 17080,
#    'iscrowd': 0,
#    'id': 929,
#    'segmentation': [[330, 3432, 757, 3432, 757, 3472, 330, 3472]]},
#   {'bbox': [435, 3720, 212, 33],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 6996,
#    'iscrowd': 0,
#    'id': 930,
#    'segmentation': [[435, 3720, 647, 3720, 647, 3753, 435, 3753]]},
#   {'bbox': [1314, 192, 224, 34],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 7616,
#    'iscrowd': 0,
#    'id': 931,
#    'segmentation': [[1314, 192, 1538, 192, 1538, 226, 1314, 226]]},
#   {'bbox': [1269, 530, 318, 42],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 13356,
#    'iscrowd': 0,
#    'id': 932,
#    'segmentation': [[1269, 530, 1587, 530, 1587, 572, 1269, 572]]},
#   {'bbox': [1205, 1127, 454, 50],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 22700,
#    'iscrowd': 0,
#    'id': 933,
#    'segmentation': [[1205, 1127, 1659, 1127, 1659, 1177, 1205, 1177]]},
#   {'bbox': [2155, 961, 325, 42],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 13650,
#    'iscrowd': 0,
#    'id': 934,
#    'segmentation': [[2155, 961, 2480, 961, 2480, 1003, 2155, 1003]]},
#   {'bbox': [2076, 1257, 487, 47],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 22889,
#    'iscrowd': 0,
#    'id': 935,
#    'segmentation': [[2076, 1257, 2563, 1257, 2563, 1304, 2076, 1304]]},
#   {'bbox': [2070, 1554, 496, 47],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 23312,
#    'iscrowd': 0,
#    'id': 936,
#    'segmentation': [[2070, 1554, 2566, 1554, 2566, 1601, 2070, 1601]]},
#   {'bbox': [2192, 1895, 250, 41],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 10250,
#    'iscrowd': 0,
#    'id': 937,
#    'segmentation': [[2192, 1895, 2442, 1895, 2442, 1936, 2192, 1936]]},
#   {'bbox': [2161, 2235, 303, 43],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 13029,
#    'iscrowd': 0,
#    'id': 938,
#    'segmentation': [[2161, 2235, 2464, 2235, 2464, 2278, 2161, 2278]]},
#   {'bbox': [2168, 2567, 292, 43],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 12556,
#    'iscrowd': 0,
#    'id': 939,
#    'segmentation': [[2168, 2567, 2460, 2567, 2460, 2610, 2168, 2610]]},
#   {'bbox': [2096, 2809, 433, 40],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 17320,
#    'iscrowd': 0,
#    'id': 940,
#    'segmentation': [[2096, 2809, 2529, 2809, 2529, 2849, 2096, 2849]]},
#   {'bbox': [2220, 3187, 184, 35],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 6440,
#    'iscrowd': 0,
#    'id': 941,
#    'segmentation': [[2220, 3187, 2404, 3187, 2404, 3222, 2220, 3222]]},
#   {'bbox': [2045, 3972, 538, 43],
#    'image_id': 248,
#    'category_id': 0,
#    'area': 23134,
#    'iscrowd': 0,
#    'id': 942,
#    'segmentation': [[2045, 3972, 2583, 3972, 2583, 4015, 2045, 4015]]},
#   {'bbox': [688, 1627, 1444, 59],
#    'image_id': 249,
#    'category_id': 0,
#    'area': 85196,
#    'iscrowd': 0,
#    'id': 943,
#    'segmentation': [[688, 1627, 2132, 1627, 2132, 1686, 688, 1686]]},
#   {'bbox': [862, 2864, 1086, 74],
#    'image_id': 249,
#    'category_id': 0,
#    'area': 80364,
#    'iscrowd': 0,
#    'id': 944,
#    'segmentation': [[862, 2864, 1948, 2864, 1948, 2938, 862, 2938]]},
#   {'bbox': [416, 3538, 374, 50],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 18700,
#    'iscrowd': 0,
#    'id': 945,
#    'segmentation': [[416, 3538, 790, 3538, 790, 3588, 416, 3588]]},
#   {'bbox': [1255, 819, 457, 44],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 20108,
#    'iscrowd': 0,
#    'id': 946,
#    'segmentation': [[1255, 819, 1712, 819, 1712, 863, 1255, 863]]},
#   {'bbox': [1341, 2301, 300, 41],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 12300,
#    'iscrowd': 0,
#    'id': 947,
#    'segmentation': [[1341, 2301, 1641, 2301, 1641, 2342, 1341, 2342]]},
#   {'bbox': [1333, 2639, 307, 30],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 9210,
#    'iscrowd': 0,
#    'id': 948,
#    'segmentation': [[1333, 2639, 1640, 2639, 1640, 2669, 1333, 2669]]},
#   {'bbox': [1358, 3101, 256, 44],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 11264,
#    'iscrowd': 0,
#    'id': 949,
#    'segmentation': [[1358, 3101, 1614, 3101, 1614, 3145, 1358, 3145]]},
#   {'bbox': [1367, 3351, 229, 35],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 8015,
#    'iscrowd': 0,
#    'id': 950,
#    'segmentation': [[1367, 3351, 1596, 3351, 1596, 3386, 1367, 3386]]},
#   {'bbox': [1381, 3775, 200, 37],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 7400,
#    'iscrowd': 0,
#    'id': 951,
#    'segmentation': [[1381, 3775, 1581, 3775, 1581, 3812, 1381, 3812]]},
#   {'bbox': [2168, 369, 398, 44],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 17512,
#    'iscrowd': 0,
#    'id': 952,
#    'segmentation': [[2168, 369, 2566, 369, 2566, 413, 2168, 413]]},
#   {'bbox': [2258, 663, 223, 43],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 9589,
#    'iscrowd': 0,
#    'id': 953,
#    'segmentation': [[2258, 663, 2481, 663, 2481, 706, 2258, 706]]},
#   {'bbox': [2206, 948, 310, 42],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 13020,
#    'iscrowd': 0,
#    'id': 954,
#    'segmentation': [[2206, 948, 2516, 948, 2516, 990, 2206, 990]]},
#   {'bbox': [2224, 1320, 288, 42],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 12096,
#    'iscrowd': 0,
#    'id': 955,
#    'segmentation': [[2224, 1320, 2512, 1320, 2512, 1362, 2224, 1362]]},
#   {'bbox': [2292, 1655, 162, 42],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 6804,
#    'iscrowd': 0,
#    'id': 956,
#    'segmentation': [[2292, 1655, 2454, 1655, 2454, 1697, 2292, 1697]]},
#   {'bbox': [2246, 2030, 255, 42],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 10710,
#    'iscrowd': 0,
#    'id': 957,
#    'segmentation': [[2246, 2030, 2501, 2030, 2501, 2072, 2246, 2072]]},
#   {'bbox': [2255, 2278, 237, 42],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 9954,
#    'iscrowd': 0,
#    'id': 958,
#    'segmentation': [[2255, 2278, 2492, 2278, 2492, 2320, 2255, 2320]]},
#   {'bbox': [2241, 2570, 255, 42],
#    'image_id': 250,
#    'category_id': 0,
#    'area': 10710,
#    'iscrowd': 0,
#    'id': 959,
#    'segmentation': [[2241, 2570, 2496, 2570, 2496, 2612, 2241, 2612]]},
#   {'bbox': [389, 1566, 385, 42],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 16170,
#    'iscrowd': 0,
#    'id': 960,
#    'segmentation': [[389, 1566, 774, 1566, 774, 1608, 389, 1608]]},
#   {'bbox': [449, 1946, 266, 36],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 9576,
#    'iscrowd': 0,
#    'id': 961,
#    'segmentation': [[449, 1946, 715, 1946, 715, 1982, 449, 1982]]},
#   {'bbox': [395, 2281, 369, 38],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 14022,
#    'iscrowd': 0,
#    'id': 962,
#    'segmentation': [[395, 2281, 764, 2281, 764, 2319, 395, 2319]]},
#   {'bbox': [329, 2814, 500, 40],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 20000,
#    'iscrowd': 0,
#    'id': 963,
#    'segmentation': [[329, 2814, 829, 2814, 829, 2854, 329, 2854]]},
#   {'bbox': [383, 3147, 396, 43],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 17028,
#    'iscrowd': 0,
#    'id': 964,
#    'segmentation': [[383, 3147, 779, 3147, 779, 3190, 383, 3190]]},
#   {'bbox': [1340, 1782, 238, 40],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 9520,
#    'iscrowd': 0,
#    'id': 965,
#    'segmentation': [[1340, 1782, 1578, 1782, 1578, 1822, 1340, 1822]]},
#   {'bbox': [1171, 2205, 569, 43],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 24467,
#    'iscrowd': 0,
#    'id': 966,
#    'segmentation': [[1171, 2205, 1740, 2205, 1740, 2248, 1171, 2248]]},
#   {'bbox': [1131, 2489, 648, 43],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 27864,
#    'iscrowd': 0,
#    'id': 967,
#    'segmentation': [[1131, 2489, 1779, 2489, 1779, 2532, 1131, 2532]]},
#   {'bbox': [1178, 2676, 561, 44],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 24684,
#    'iscrowd': 0,
#    'id': 968,
#    'segmentation': [[1178, 2676, 1739, 2676, 1739, 2720, 1178, 2720]]},
#   {'bbox': [1255, 2970, 411, 38],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 15618,
#    'iscrowd': 0,
#    'id': 969,
#    'segmentation': [[1255, 2970, 1666, 2970, 1666, 3008, 1255, 3008]]},
#   {'bbox': [1124, 3262, 679, 41],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 27839,
#    'iscrowd': 0,
#    'id': 970,
#    'segmentation': [[1124, 3262, 1803, 3262, 1803, 3303, 1124, 3303]]},
#   {'bbox': [1261, 3518, 393, 44],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 17292,
#    'iscrowd': 0,
#    'id': 971,
#    'segmentation': [[1261, 3518, 1654, 3518, 1654, 3562, 1261, 3562]]},
#   {'bbox': [1303, 3848, 311, 44],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 13684,
#    'iscrowd': 0,
#    'id': 972,
#    'segmentation': [[1303, 3848, 1614, 3848, 1614, 3892, 1303, 3892]]},
#   {'bbox': [2185, 1557, 302, 41],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 12382,
#    'iscrowd': 0,
#    'id': 973,
#    'segmentation': [[2185, 1557, 2487, 1557, 2487, 1598, 2185, 1598]]},
#   {'bbox': [2083, 1857, 501, 38],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 19038,
#    'iscrowd': 0,
#    'id': 974,
#    'segmentation': [[2083, 1857, 2584, 1857, 2584, 1895, 2083, 1895]]},
#   {'bbox': [2134, 2105, 402, 42],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 16884,
#    'iscrowd': 0,
#    'id': 975,
#    'segmentation': [[2134, 2105, 2536, 2105, 2536, 2147, 2134, 2147]]},
#   {'bbox': [2004, 2356, 653, 40],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 26120,
#    'iscrowd': 0,
#    'id': 976,
#    'segmentation': [[2004, 2356, 2657, 2356, 2657, 2396, 2004, 2396]]},
#   {'bbox': [2176, 3014, 316, 30],
#    'image_id': 251,
#    'category_id': 0,
#    'area': 9480,
#    'iscrowd': 0,
#    'id': 977,
#    'segmentation': [[2176, 3014, 2492, 3014, 2492, 3044, 2176, 3044]]},
#   {'bbox': [115, 68, 722, 59],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 42598,
#    'iscrowd': 0,
#    'id': 978,
#    'segmentation': [[115, 68, 837, 68, 837, 127, 115, 127]]},
#   {'bbox': [107, 531, 850, 105],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 89250,
#    'iscrowd': 0,
#    'id': 979,
#    'segmentation': [[107, 531, 957, 531, 957, 636, 107, 636]]},
#   {'bbox': [1242, 651, 344, 41],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 14104,
#    'iscrowd': 0,
#    'id': 980,
#    'segmentation': [[1242, 651, 1586, 651, 1586, 692, 1242, 692]]},
#   {'bbox': [1204, 1078, 422, 30],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 12660,
#    'iscrowd': 0,
#    'id': 981,
#    'segmentation': [[1204, 1078, 1626, 1078, 1626, 1108, 1204, 1108]]},
#   {'bbox': [1159, 1598, 513, 50],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 25650,
#    'iscrowd': 0,
#    'id': 982,
#    'segmentation': [[1159, 1598, 1672, 1598, 1672, 1648, 1159, 1648]]},
#   {'bbox': [1159, 2957, 509, 35],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 17815,
#    'iscrowd': 0,
#    'id': 983,
#    'segmentation': [[1159, 2957, 1668, 2957, 1668, 2992, 1159, 2992]]},
#   {'bbox': [1306, 3461, 216, 41],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 8856,
#    'iscrowd': 0,
#    'id': 984,
#    'segmentation': [[1306, 3461, 1522, 3461, 1522, 3502, 1306, 3502]]},
#   {'bbox': [1998, 60, 596, 47],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 28012,
#    'iscrowd': 0,
#    'id': 985,
#    'segmentation': [[1998, 60, 2594, 60, 2594, 107, 1998, 107]]},
#   {'bbox': [2103, 291, 377, 43],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 16211,
#    'iscrowd': 0,
#    'id': 986,
#    'segmentation': [[2103, 291, 2480, 291, 2480, 334, 2103, 334]]},
#   {'bbox': [2120, 1237, 356, 42],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 14952,
#    'iscrowd': 0,
#    'id': 987,
#    'segmentation': [[2120, 1237, 2476, 1237, 2476, 1279, 2120, 1279]]},
#   {'bbox': [2215, 1483, 159, 42],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 6678,
#    'iscrowd': 0,
#    'id': 988,
#    'segmentation': [[2215, 1483, 2374, 1483, 2374, 1525, 2215, 1525]]},
#   {'bbox': [2186, 1821, 220, 43],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 9460,
#    'iscrowd': 0,
#    'id': 989,
#    'segmentation': [[2186, 1821, 2406, 1821, 2406, 1864, 2186, 1864]]},
#   {'bbox': [2143, 2155, 309, 43],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 13287,
#    'iscrowd': 0,
#    'id': 990,
#    'segmentation': [[2143, 2155, 2452, 2155, 2452, 2198, 2143, 2198]]},
#   {'bbox': [2172, 2448, 246, 33],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 8118,
#    'iscrowd': 0,
#    'id': 991,
#    'segmentation': [[2172, 2448, 2418, 2448, 2418, 2481, 2172, 2481]]},
#   {'bbox': [2100, 2996, 388, 34],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 13192,
#    'iscrowd': 0,
#    'id': 992,
#    'segmentation': [[2100, 2996, 2488, 2996, 2488, 3030, 2100, 3030]]},
#   {'bbox': [2030, 3505, 516, 47],
#    'image_id': 252,
#    'category_id': 0,
#    'area': 24252,
#    'iscrowd': 0,
#    'id': 993,
#    'segmentation': [[2030, 3505, 2546, 3505, 2546, 3552, 2030, 3552]]},
#   {'bbox': [265, 403, 598, 46],
#    'image_id': 253,
#    'category_id': 0,
#    'area': 27508,
#    'iscrowd': 0,
#    'id': 994,
#    'segmentation': [[265, 403, 863, 403, 863, 449, 265, 449]]},
#   {'bbox': [440, 871, 245, 40],
#    'image_id': 253,
#    'category_id': 0,
#    'area': 9800,
#    'iscrowd': 0,
#    'id': 995,
#    'segmentation': [[440, 871, 685, 871, 685, 911, 440, 911]]},
#   {'bbox': [268, 2097, 596, 43],
#    'image_id': 253,
#    'category_id': 0,
#    'area': 25628,
#    'iscrowd': 0,
#    'id': 996,
#    'segmentation': [[268, 2097, 864, 2097, 864, 2140, 268, 2140]]},
#   {'bbox': [213, 2974, 724, 88],
#    'image_id': 253,
#    'category_id': 0,
#    'area': 63712,
#    'iscrowd': 0,
#    'id': 997,
#    'segmentation': [[213, 2974, 937, 2974, 937, 3062, 213, 3062]]},
#   {'bbox': [357, 3672, 425, 44],
#    'image_id': 253,
#    'category_id': 0,
#    'area': 18700,
#    'iscrowd': 0,
#    'id': 998,
#    'segmentation': [[357, 3672, 782, 3672, 782, 3716, 357, 3716]]},
#   {'bbox': [1234, 83, 418, 46],
#    'image_id': 253,
#    'category_id': 0,
#    'area': 19228,
#    'iscrowd': 0,
#    'id': 999,
#    'segmentation': [[1234, 83, 1652, 83, 1652, 129, 1234, 129]]},
#   {'bbox': [1225, 579, 427, 43],
#    'image_id': 253,
#    'category_id': 0,
#    'area': 18361,
#    'iscrowd': 0,
#    'id': 1000,
#    'segmentation': [[1225, 579, 1652, 579, 1652, 622, 1225, 622]]},
#   ...],
#  'categories': [{'supercategory': 'article_title',
#    'name': 'article_title',
#    'id': 0},
#   {'supercategory': 'death_notice', 'name': 'death_notice', 'id': 1},
#   {'supercategory': 'table', 'name': 'table', 'id': 2},
#   {'supercategory': 'image', 'name': 'image', 'id': 3},
#   {'supercategory': 'image_caption', 'name': 'image_caption', 'id': 4},
#   {'supercategory': 'ad', 'name': 'ad', 'id': 5},
#   {'supercategory': 'weather', 'name': 'weather', 'id': 6},
#   {'supercategory': 'article', 'name': 'article', 'id': 7},
#   {'supercategory': 'earrings', 'name': 'earrings', 'id': 8}]}

# %%
coco_format.keys()
# Out:
# dict_keys(['images', 'annotations', 'categories'])

# %%
def convert_numpy(obj):
    if isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()  # Convert arrays to lists
    raise TypeError(f"Type {type(obj)} not serializable")

# save to JSON
with open(f"/scratch/students/danae/data/model_data_format/yolo/{coco_fn}.json", "w") as f:
    json.dump(coco_format, f, indent=1, default=convert_numpy)
